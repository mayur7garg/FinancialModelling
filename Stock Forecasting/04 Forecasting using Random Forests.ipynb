# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import constants as cnst
import stock_utils as su

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = su.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['HDFCBANK', 'ITBEES', 'JUBLFOOD']

# %%
STOCK_SYMBOL = stock_symbols[2]
STOCK_SYMBOL
# Out:
# 'JUBLFOOD'

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Stock data

# %%
stock_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-processed.parquet')
)

stock_df
# Out:
#            Date     Open     High      Low     LTP    Close     VWAP    52W H  \
# 0    2020-01-01  1656.95  1673.00  1652.80  1664.6  1663.15  1664.37  1673.00
# 1    2020-01-02  1665.00  1688.35  1655.50  1686.0  1682.70  1675.06  1688.35
# 2    2020-01-03  1681.00  1696.90  1668.05  1679.0  1682.75  1685.46  1696.90
# 3    2020-01-06  1670.30  1688.85  1664.25  1679.0  1679.60  1676.81  1696.90
# 4    2020-01-07  1688.00  1702.50  1684.05  1689.4  1693.65  1693.57  1702.50
# ...         ...      ...      ...      ...     ...      ...      ...      ...
# 1027 2024-01-29   508.75   518.45   504.10   518.0   513.15   510.72   586.95
# 1028 2024-01-30   517.15   521.90   508.05   513.0   510.15   513.73   586.95
# 1029 2024-01-31   514.00   526.15   509.50   518.2   519.55   518.54   586.95
# 1030 2024-02-01   513.00   518.45   498.10   501.4   501.90   505.93   586.95
# 1031 2024-02-02   504.70   505.85   493.80   495.1   494.85   498.24   586.95
#
#        52W L   Volume         Value  #Trades  Range  IsGreen  Is52WLow  \
# 0     1077.9  1142694  1.901871e+09    27428  20.20        1         0
# 1     1077.9   840514  1.407907e+09    26148  32.85        1         0
# 2     1077.9   975751  1.644585e+09    26219  28.85        1         0
# 3     1077.9   586899  9.841203e+08    20012  24.60        1         0
# 4     1077.9   845385  1.431717e+09    23848  18.45        1         0
# ...      ...      ...           ...      ...    ...      ...       ...
# 1027   412.1  6212204  3.172690e+09    77868  14.35        1         0
# 1028   412.1  2464481  1.266071e+09    34342  13.85        0         0
# 1029   412.1  4259420  2.208667e+09    92424  16.65        1         0
# 1030   412.1  6644517  3.361652e+09   131585  20.35        0         0
# 1031   412.1  4445535  2.214926e+09   102970  12.05        0         0
#
#       Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0             1    1      1  2020        2          1        1
# 1             1    2      1  2020        3          2        1
# 2             1    3      1  2020        4          3        1
# 3             0    6      1  2020        0          6        1
# 4             1    7      1  2020        1          7        1
# ...         ...  ...    ...   ...      ...        ...      ...
# 1027          0   29      1  2024        0         29        1
# 1028          0   30      1  2024        1         30        1
# 1029          0   31      1  2024        2         31        1
# 1030          0    1      2  2024        3         32        1
# 1031          0    2      2  2024        4         33        1
#
#       DaysSinceLastTradingSession  Close 7MA  Close 15MA  Close 30MA  \
# 0                               1    1663.15     1663.15     1663.15
# 1                               1    1672.93     1672.93     1672.93
# 2                               1    1676.20     1676.20     1676.20
# 3                               3    1677.05     1677.05     1677.05
# 4                               1    1680.37     1680.37     1680.37
# ...                           ...        ...         ...         ...
# 1027                            4     520.95      524.86      544.52
# 1028                            1     518.93      523.25      542.67
# 1029                            1     517.20      522.91      541.35
# 1030                            1     514.16      521.51      539.25
# 1031                            1     510.48      519.32      537.00
#
#       Close 60MA  Range 7MA  Range 15MA  Range 30MA  Range 60MA  VWAP 7MA  \
# 0        1663.15      20.20       20.20       20.20       20.20   1664.37
# 1        1672.93      26.52       26.52       26.52       26.52   1669.72
# 2        1676.20      27.30       27.30       27.30       27.30   1674.96
# 3        1677.05      26.62       26.62       26.62       26.62   1675.42
# 4        1680.37      24.99       24.99       24.99       24.99   1679.05
# ...          ...        ...         ...         ...         ...       ...
# 1027      539.78      14.04       13.58       13.55       11.82    520.32
# 1028      539.93      14.17       12.90       13.50       11.96    519.10
# 1029      540.14      15.08       12.91       13.80       12.12    517.10
# 1030      540.04      15.99       13.71       13.99       12.34    514.12
# 1031      539.89      15.61       13.99       13.41       12.40    511.22
#
#       VWAP 15MA  VWAP 30MA  VWAP 60MA  Volume 7MA  Volume 15MA  Volume 30MA  \
# 0       1664.37    1664.37    1664.37     1142694      1142694      1142694
# 1       1669.72    1669.72    1669.72      991604       991604       991604
# 2       1674.96    1674.96    1674.96      986319       986319       986319
# 3       1675.42    1675.42    1675.42      886464       886464       886464
# 4       1679.05    1679.05    1679.05      878248       878248       878248
# ...         ...        ...        ...         ...          ...          ...
# 1027     525.42     545.46     540.22     3169424      2587621      2427123
# 1028     523.67     543.66     540.42     3160963      2591987      2453664
# 1029     522.96     542.20     540.61     3445825      2697419      2544398
# 1030     521.94     540.13     540.57     4301178      3028044      2686249
# 1031     520.01     537.63     540.44     4536900      3189869      2620217
#
#       Volume 60MA   Value 7MA  Value 15MA  Value 30MA  Value 60MA  \
# 0         1142694  1901871196  1901871196  1901871196  1901871196
# 1          991604  1654889284  1654889284  1654889284  1654889284
# 2          986319  1651454555  1651454555  1651454555  1651454555
# 3          886464  1484620980  1484620980  1484620980  1484620980
# 4          878248  1474040255  1474040255  1474040255  1474040255
# ...           ...         ...         ...         ...         ...
# 1027      2134424  1640447875  1353563596  1320179854  1158761061
# 1028      2166395  1633013466  1351599355  1330811888  1175295089
# 1029      2211641  1776201812  1404377593  1375624151  1199049589
# 1030      2305913  2206989109  1569930520  1442436250  1246708400
# 1031      2368419  2316341035  1646665403  1393467009  1277763128
#
#       #Trades 7MA  #Trades 15MA  #Trades 30MA  #Trades 60MA  Target 3D  \
# 0           27428         27428         27428         27428    1679.60
# 1           26788         26788         26788         26788    1693.65
# 2           26598         26598         26598         26598    1725.70
# 3           24951         24951         24951         24951    1714.30
# 4           24731         24731         24731         24731    1727.80
# ...           ...           ...           ...           ...        ...
# 1027        64065         56940         50662         42078     501.90
# 1028        58966         54449         50569         42443     494.85
# 1029        60480         58094         52034         43717        NaN
# 1030        76467         64211         54870         45393        NaN
# 1031        77438         68027         54957         46786        NaN
#
#       Target 7D  Target 15D  Target 30D
# 0       1727.80     1773.80     1825.55
# 1       1731.35     1793.55     1820.00
# 2       1720.50     1810.10     1835.10
# 3       1753.45     1822.90     1812.60
# 4       1746.70     1754.30     1833.05
# ...         ...         ...         ...
# 1027        NaN         NaN         NaN
# 1028        NaN         NaN         NaN
# 1029        NaN         NaN         NaN
# 1030        NaN         NaN         NaN
# 1031        NaN         NaN         NaN
#
# [1032 rows x 51 columns]

# %% [markdown]
# ### Standardized data

# %%
standardized_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-standardized.parquet')
)

standardized_df
# Out:
#        Open   High    Low    LTP   VWAP  52W H  52W L  IsGreen  Is52WLow  \
# 0     0.996  1.006  0.994  1.001  1.001  1.006  0.648        1         0
# 1     0.989  1.003  0.984  1.002  0.995  1.003  0.641        1         0
# 2     0.999  1.008  0.991  0.998  1.002  1.008  0.641        1         0
# 3     0.994  1.006  0.991  1.000  0.998  1.010  0.642        1         0
# 4     0.997  1.005  0.994  0.997  1.000  1.005  0.636        1         0
# ...     ...    ...    ...    ...    ...    ...    ...      ...       ...
# 1027  0.991  1.010  0.982  1.009  0.995  1.144  0.803        1         0
# 1028  1.014  1.023  0.996  1.006  1.007  1.151  0.808        0         0
# 1029  0.989  1.013  0.981  0.997  0.998  1.130  0.793        1         0
# 1030  1.022  1.033  0.992  0.999  1.008  1.169  0.821        0         0
# 1031  1.020  1.022  0.998  1.001  1.007  1.186  0.833        0         0
#
#       Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0             1    1      1  2020        2          1        1
# 1             1    2      1  2020        3          2        1
# 2             1    3      1  2020        4          3        1
# 3             0    6      1  2020        0          6        1
# 4             1    7      1  2020        1          7        1
# ...         ...  ...    ...   ...      ...        ...      ...
# 1027          0   29      1  2024        0         29        1
# 1028          0   30      1  2024        1         30        1
# 1029          0   31      1  2024        2         31        1
# 1030          0    1      2  2024        3         32        1
# 1031          0    2      2  2024        4         33        1
#
#       DaysSinceLastTradingSession  Close 7MA  Close 15MA  Close 30MA  \
# 0                               1      1.000       1.000       1.000
# 1                               1      0.994       0.994       0.994
# 2                               1      0.996       0.996       0.996
# 3                               3      0.998       0.998       0.998
# 4                               1      0.992       0.992       0.992
# ...                           ...        ...         ...         ...
# 1027                            4      1.015       1.023       1.061
# 1028                            1      1.017       1.026       1.064
# 1029                            1      0.995       1.006       1.042
# 1030                            1      1.024       1.039       1.074
# 1031                            1      1.032       1.049       1.085
#
#       Close 60MA  Range 7MA  Range 15MA  Range 30MA  Range 60MA  VWAP 7MA  \
# 0          1.000      0.012       0.012       0.012       0.012     1.001
# 1          0.994      0.016       0.016       0.016       0.016     0.992
# 2          0.996      0.016       0.016       0.016       0.016     0.995
# 3          0.998      0.016       0.016       0.016       0.016     0.998
# 4          0.992      0.015       0.015       0.015       0.015     0.991
# ...          ...        ...         ...         ...         ...       ...
# 1027       1.052      0.027       0.026       0.026       0.023     1.014
# 1028       1.058      0.028       0.025       0.026       0.023     1.018
# 1029       1.040      0.029       0.025       0.027       0.023     0.995
# 1030       1.076      0.032       0.027       0.028       0.025     1.024
# 1031       1.091      0.032       0.028       0.027       0.025     1.033
#
#       VWAP 15MA  VWAP 30MA  VWAP 60MA  Volume 7MA  Volume 15MA  Volume 30MA  \
# 0         1.001      1.001      1.001       1.000        1.000        1.000
# 1         0.992      0.992      0.992       1.180        1.180        1.180
# 2         0.995      0.995      0.995       1.011        1.011        1.011
# 3         0.998      0.998      0.998       1.510        1.510        1.510
# 4         0.991      0.991      0.991       1.039        1.039        1.039
# ...         ...        ...        ...         ...          ...          ...
# 1027      1.024      1.063      1.053       0.510        0.417        0.391
# 1028      1.027      1.066      1.059       1.283        1.052        0.996
# 1029      1.007      1.044      1.041       0.809        0.633        0.597
# 1030      1.040      1.076      1.077       0.647        0.456        0.404
# 1031      1.051      1.086      1.092       1.021        0.718        0.589
#
#       Volume 60MA  Value 7MA  Value 15MA  Value 30MA  Value 60MA  #Trades 7MA  \
# 0           1.000      1.000       1.000       1.000       1.000        1.000
# 1           1.180      1.175       1.175       1.175       1.175        1.024
# 2           1.011      1.004       1.004       1.004       1.004        1.014
# 3           1.510      1.509       1.509       1.509       1.509        1.247
# 4           1.039      1.030       1.030       1.030       1.030        1.037
# ...           ...        ...         ...         ...         ...          ...
# 1027        0.344      0.517       0.427       0.416       0.365        0.823
# 1028        0.879      1.290       1.068       1.051       0.928        1.717
# 1029        0.519      0.804       0.636       0.623       0.543        0.654
# 1030        0.347      0.657       0.467       0.429       0.371        0.581
# 1031        0.533      1.046       0.743       0.629       0.577        0.752
#
#       #Trades 15MA  #Trades 30MA  #Trades 60MA  Target 3D  Target 7D  \
# 0            1.000         1.000         1.000      1.010      1.039
# 1            1.024         1.024         1.024      1.007      1.029
# 2            1.014         1.014         1.014      1.026      1.022
# 3            1.247         1.247         1.247      1.021      1.044
# 4            1.037         1.037         1.037      1.020      1.031
# ...            ...           ...           ...        ...        ...
# 1027         0.731         0.651         0.540      0.978        NaN
# 1028         1.585         1.473         1.236      0.970        NaN
# 1029         0.629         0.563         0.473        NaN        NaN
# 1030         0.488         0.417         0.345        NaN        NaN
# 1031         0.661         0.534         0.454        NaN        NaN
#
#       Target 15D  Target 30D
# 0          1.067       1.098
# 1          1.066       1.082
# 2          1.076       1.091
# 3          1.085       1.079
# 4          1.036       1.082
# ...          ...         ...
# 1027         NaN         NaN
# 1028         NaN         NaN
# 1029         NaN         NaN
# 1030         NaN         NaN
# 1031         NaN         NaN
#
# [1032 rows x 45 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = standardized_df.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
standardized_df[target_cols].describe()
# Out:
#          Target 3D   Target 7D   Target 15D   Target 30D
# count  1029.000000  1025.00000  1017.000000  1002.000000
# mean      0.999603     0.99888     0.997663     0.995811
# std       0.057643     0.08587     0.125663     0.180719
# min       0.197000     0.18700     0.169000     0.166000
# 25%       0.982000     0.97300     0.955000     0.931000
# 50%       1.001000     1.00400     1.004000     1.019000
# 75%       1.023000     1.03600     1.061000     1.096000
# max       1.220000     1.23200     1.222000     1.353000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = standardized_df[standardized_df[target_col].notnull()].drop(columns = target_cols).copy()
    y = standardized_df[standardized_df[target_col].notnull()][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = standardized_df.drop(columns = target_cols).columns.to_list()
)

expected_errors = {}

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 10,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(y, preds):
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {mean_squared_error(y, preds, squared = False):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

def expected_error(y, preds):
    return mean_squared_error(y, preds, squared = False)

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (1029, 41)
# y.shape: (1029,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.341125      0.022682         0.043078        0.002382
# 5       0.411941      0.037371         0.047566        0.007922
# 8       0.326654      0.030949         0.041847        0.003999
# 1       0.224469      0.005449         0.030149        0.000887
# 4       0.229358      0.014892         0.032408        0.005370
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 5                125               1.0               sqrt               5
# 8                100               1.0               sqrt               4
# 1                 75               1.0               sqrt               5
# 4                 75              0.75               log2               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.105762
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.170757
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.287024
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.197486
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.202419
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.203451          -0.042683          -0.145410          -0.597828
# 5          -0.180884          -0.049039          -0.243704          -0.639029
# 8          -0.222525          -0.048034          -0.082304          -0.703645
# 1          -0.166144          -0.050774          -0.523577          -0.546341
# 4          -0.297502          -0.045524          -0.246255          -1.098945
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.219027        0.196508                1
# 5        -0.256683        0.201297                2
# 8        -0.268706        0.234556                3
# 1        -0.296864        0.200580                4
# 4        -0.378129        0.370126                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.058
# R2: 0.382
# MSE: 0.045
# MAE: 0.027

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date   Close  Target 3D  Pred Target 3D
# 1019 2024-01-16  530.40     531.65          528.03
# 1020 2024-01-17  527.70     523.20          525.07
# 1021 2024-01-18  524.30     520.60          521.89
# 1022 2024-01-19  531.65     525.50          529.16
# 1023 2024-01-20  523.20     508.25          520.60
# 1024 2024-01-23  520.60     513.15          517.95
# 1025 2024-01-24  525.50     510.15          522.59
# 1026 2024-01-25  508.25     519.55          505.55
# 1027 2024-01-29  513.15     501.90          509.95
# 1028 2024-01-30  510.15     494.85          506.27

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (1025, 41)
# y.shape: (1025,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.334493      0.027900         0.041558        0.004745
# 5       0.405978      0.016638         0.047550        0.005247
# 8       0.295192      0.002531         0.040395        0.003196
# 4       0.266855      0.021942         0.036038        0.005487
# 1       0.253323      0.015195         0.031349        0.000811
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 5                125               1.0               sqrt               5
# 8                100               1.0               sqrt               4
# 4                 75              0.75               log2               5
# 1                 75               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.595097
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.858605
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.727444
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.595197
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.771311
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.213687          -0.105277          -0.524685          -1.512798
# 5          -0.350368          -0.103269          -0.277671          -2.018555
# 8          -0.237336          -0.098432          -0.967495          -1.624255
# 4          -0.274468          -0.103693          -0.488965          -2.244738
# 1          -0.322124          -0.106815          -0.866732          -1.953157
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.590309        0.496471                1
# 5        -0.721694        0.695425                2
# 8        -0.730993        0.547301                3
# 4        -0.741412        0.770691                4
# 1        -0.804028        0.639349                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.086
# R2: 0.523
# MSE: 0.059
# MAE: 0.039

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date   Close  Target 7D  Pred Target 7D
# 1015 2024-01-10  522.90     531.65          517.84
# 1016 2024-01-11  527.70     523.20          522.65
# 1017 2024-01-12  525.65     520.60          520.12
# 1018 2024-01-15  532.95     525.50          528.18
# 1019 2024-01-16  530.40     508.25          524.38
# 1020 2024-01-17  527.70     513.15          522.23
# 1021 2024-01-18  524.30     510.15          519.13
# 1022 2024-01-19  531.65     519.55          526.49
# 1023 2024-01-20  523.20     501.90          513.65
# 1024 2024-01-23  520.60     494.85          510.76

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (1017, 41)
# y.shape: (1017,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.296049      0.006590         0.042908        0.001182
# 8       0.321486      0.019383         0.041836        0.003247
# 3       0.261965      0.017718         0.033827        0.004036
# 5       0.436917      0.034237         0.050057        0.004468
# 1       0.272377      0.024552         0.036435        0.005841
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 8                100               1.0               sqrt               4
# 3                 75               1.0               0.25               4
# 5                125               1.0               sqrt               5
# 1                 75               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.589624
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.819337
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.952617
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.949453
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.832803
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.464989          -0.165404          -0.834354          -1.782239
# 8          -0.349367          -0.181787          -1.111410          -1.747220
# 3          -0.463546          -0.215755          -1.670887          -1.482192
# 5          -0.525073          -0.209537          -1.140407          -2.022056
# 1          -0.674324          -0.210947          -1.212188          -2.258859
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.767322        0.551332                1
# 8        -0.841824        0.560551                2
# 3        -0.956999        0.561858                3
# 5        -0.969305        0.618473                4
# 1        -1.037824        0.689815                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.126
# R2: 0.597
# MSE: 0.080
# MAE: 0.055

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date   Close  Target 15D  Pred Target 15D
# 1007 2023-12-29  565.05      531.65           566.03
# 1008 2024-01-01  561.55      523.20           547.51
# 1009 2024-01-02  558.60      520.60           537.53
# 1010 2024-01-03  554.00      525.50           537.08
# 1011 2024-01-04  561.15      508.25           545.20
# 1012 2024-01-05  555.55      513.15           542.46
# 1013 2024-01-08  534.35      510.15           518.73
# 1014 2024-01-09  524.60      519.55           507.37
# 1015 2024-01-10  522.90      501.90           506.36
# 1016 2024-01-11  527.70      494.85           511.65

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (1002, 41)
# y.shape: (1002,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.342728      0.024187         0.044693        0.001511
# 8       0.355658      0.023491         0.045982        0.003799
# 4       0.241629      0.004278         0.042194        0.022669
# 0       0.396392      0.062970         0.047873        0.005868
# 1       0.247140      0.006867         0.035623        0.005137
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 8                100               1.0               sqrt               4
# 4                 75              0.75               log2               5
# 0                100               1.0               log2               5
# 1                 75               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -1.151616
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -1.455326
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -1.641196
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -1.532617
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -1.445402
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -1.334395          -0.570081          -1.883484          -3.091856
# 8          -1.255291          -0.594135          -2.151575          -2.888354
# 4          -1.182404          -0.556987          -1.465153          -4.042478
# 0          -1.456461          -0.591991          -2.367521          -3.308106
# 1          -1.374358          -0.615038          -2.180784          -4.518471
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -1.606287        0.853010                1
# 8        -1.668936        0.786365                2
# 4        -1.777644        1.190803                3
# 0        -1.851339        0.920009                4
# 1        -2.026811        1.340814                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.181
# R2: 0.644
# MSE: 0.108
# MAE: 0.078

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date   Close  Target 30D  Pred Target 30D
# 992  2023-12-07  561.00      531.65           559.06
# 993  2023-12-08  559.75      523.20           557.41
# 994  2023-12-11  560.55      520.60           558.96
# 995  2023-12-12  558.30      525.50           558.55
# 996  2023-12-13  556.15      508.25           558.21
# 997  2023-12-14  569.05      513.15           567.13
# 998  2023-12-15  565.45      510.15           564.57
# 999  2023-12-18  559.10      519.55           558.71
# 1000 2023-12-19  564.95      501.90           563.52
# 1001 2023-12-20  562.35      494.85           563.18

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# DayOfYear                          5.7        5.8        12.0        10.7
# Month                              2.3        4.6         7.4         9.3
# Range 60MA                         3.6        4.2         7.8         8.0
# DaysSinceLastTradingSession        9.6        6.9         2.8         1.4
# Range 30MA                         4.6        4.1         5.1         4.3
# 52W H                              3.6        3.1         4.1         6.6
# Close 60MA                         3.2        2.8         5.1         5.9
# VWAP 60MA                          2.2        3.4         5.2         5.8
# Range 15MA                         4.4        5.9         2.4         3.9
# 52W L                              1.8        6.4         2.9         4.2
# Range 7MA                          2.4        4.1         3.9         4.4
# Close 30MA                         3.1        5.5         3.7         1.7
# VWAP 30MA                          3.2        4.5         3.7         1.9
# #Trades 30MA                       2.9        4.3         3.4         2.5
# Year                               0.7        1.8         4.6         5.7
# Quarter                            1.4        3.0         3.3         4.7
# VWAP 15MA                          4.0        2.9         3.1         1.5
# Close 15MA                         2.9        2.9         3.1         2.0
# #Trades 60MA                       1.8        2.4         2.6         1.3
# VWAP 7MA                           3.6        2.0         1.0         0.6
# Volume 30MA                        2.3        2.1         1.6         1.2
# Close 7MA                          2.7        2.3         1.4         0.5
# #Trades 15MA                       2.3        1.8         1.9         0.7
# Value 60MA                         2.1        1.1         0.8         1.1
# Day                                1.3        1.9         0.8         0.9
# High                               2.0        1.2         0.4         1.0
# Open                               2.6        1.2         0.3         0.5
# VWAP                               3.1        0.5         0.4         0.5
# Volume 15MA                        2.2        0.8         0.9         0.7
# LTP                                2.2        0.7         1.0         0.6
# Low                                2.2        0.6         0.5         1.0
# #Trades 7MA                        1.6        1.0         0.7         1.0
# Volume 60MA                        2.0        0.5         0.6         1.2
# Value 15MA                         1.4        0.8         0.6         0.9
# Value 30MA                         0.5        1.5         0.5         0.9
# Value 7MA                          1.1        0.6         0.1         0.3
# Volume 7MA                         0.6        0.6         0.2         0.3
# Weekday                            1.0        0.4         0.0         0.0
# IsGreen                            0.1        0.1         0.0         0.1
# Is52WLow                           0.0        0.0         0.0         0.2
# Is52WHigh                          0.0        0.0         0.0         0.0
#
#                              Mean
# DayOfYear                     8.5
# Month                         5.9
# Range 60MA                    5.9
# DaysSinceLastTradingSession   5.2
# Range 30MA                    4.5
# 52W H                         4.4
# Close 60MA                    4.3
# VWAP 60MA                     4.2
# Range 15MA                    4.1
# 52W L                         3.8
# Range 7MA                     3.7
# Close 30MA                    3.5
# VWAP 30MA                     3.3
# #Trades 30MA                  3.3
# Year                          3.2
# Quarter                       3.1
# VWAP 15MA                     2.9
# Close 15MA                    2.7
# #Trades 60MA                  2.0
# VWAP 7MA                      1.8
# Volume 30MA                   1.8
# Close 7MA                     1.7
# #Trades 15MA                  1.7
# Value 60MA                    1.3
# Day                           1.2
# High                          1.2
# Open                          1.2
# VWAP                          1.1
# Volume 15MA                   1.1
# LTP                           1.1
# Low                           1.1
# #Trades 7MA                   1.1
# Volume 60MA                   1.1
# Value 15MA                    0.9
# Value 30MA                    0.8
# Value 7MA                     0.5
# Volume 7MA                    0.4
# Weekday                       0.3
# IsGreen                       0.1
# Is52WLow                      0.0
# Is52WHigh                     0.0

# %% [markdown]
# ## Forecasts

# %%
stock_df.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-10:, :]
# Out:
#            Date   Close  Pred Target 3D  Pred Target 7D  Pred Target 15D  \
# 1022 2024-01-19  531.65          529.16          526.49           515.57
# 1023 2024-01-20  523.20          520.60          513.65           489.53
# 1024 2024-01-23  520.60          517.95          510.76           505.40
# 1025 2024-01-24  525.50          522.59          519.87           507.05
# 1026 2024-01-25  508.25          505.55          496.83           482.29
# 1027 2024-01-29  513.15          509.95          501.79           487.39
# 1028 2024-01-30  510.15          506.27          495.44           478.52
# 1029 2024-01-31  519.55          516.26          507.92           492.07
# 1030 2024-02-01  501.90          500.32          494.18           473.14
# 1031 2024-02-02  494.85          492.00          487.22           466.03
#
#       Pred Target 30D
# 1022           490.53
# 1023           480.88
# 1024           473.21
# 1025           483.22
# 1026           454.05
# 1027           465.50
# 1028           461.95
# 1029           475.77
# 1030           446.33
# 1031           437.97

# %%
latest_preds = stock_df.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-1]
print(f"Date: {latest_preds['Date'].date()}")
print(f"Close: {latest_preds['Close']}")

for pred in expected_errors.keys():
    print(f"{pred}: {latest_preds[pred]} ± {expected_errors[pred] * latest_preds['Close']:.2f}")
# Out:
# Date: 2024-02-02
# Close: 494.85
# Pred Target 3D: 492.0 ± 22.42
# Pred Target 7D: 487.22 ± 29.33
# Pred Target 15D: 466.03 ± 39.44
# Pred Target 30D: 437.97 ± 53.33
