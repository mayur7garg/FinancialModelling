# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import constants as cnst
import stock_utils as su

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# SCREENER_EPS_DATA_DIR = PosixPath('../data/Screener.in/EPS') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = su.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['DEEPAKFERT', 'HDFCBANK', 'INDIGOPNTS', 'ITBEES', 'JUBLFOOD']

# %%
STOCK_SYMBOL = stock_symbols[1]
STOCK_SYMBOL
# Out:
# 'HDFCBANK'

# %% [markdown]
# ## Loading stock data

# %%
stock_data = su.StockData(STOCK_SYMBOL)
stock_data
# Out:
# Symbol: HDFCBANK
# Total records: 1049
# First record: 2020-01-01
# Last record: 2024-02-26

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = stock_data.standardized.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
stock_data.standardized[target_cols].describe()
# Out:
#          Target 3D    Target 7D   Target 15D   Target 30D
# count  1046.000000  1042.000000  1034.000000  1019.000000
# mean      1.000772     1.001874     1.003761     1.008427
# std       0.030943     0.046347     0.065198     0.088580
# min       0.820000     0.718000     0.668000     0.629000
# 25%       0.985000     0.977000     0.967000     0.959500
# 50%       1.000000     1.002000     1.001500     1.006000
# 75%       1.016750     1.025000     1.042000     1.058000
# max       1.178000     1.219000     1.231000     1.322000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = stock_data.standardized[
        stock_data.standardized[target_col].notnull()
    ].drop(columns = target_cols).copy()
    y = stock_data.standardized[
        stock_data.standardized[target_col].notnull()
    ][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = stock_data.standardized.drop(columns = target_cols).columns.to_list()
)

expected_errors = {}

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 12,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(y, preds):
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {mean_squared_error(y, preds, squared = False):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

def expected_error(y, preds):
    return mean_squared_error(y, preds, squared = False)

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (1046, 43)
# y.shape: (1046,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 75, 'max_samples': 1.0, 'max_features': 0.25, 'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3        0.213845      0.012613         0.031345        0.002105
# 11       0.263777      0.002780         0.040680        0.007036
# 8        0.271870      0.020119         0.043970        0.005175
# 9        0.262344      0.002359         0.040962        0.001338
# 0        0.353297      0.048518         0.037397        0.005440
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 3                  75               1.0               0.25               4
# 11                100              0.75               0.25               4
# 8                 100               1.0               sqrt               4
# 9                 100              0.75               log2               4
# 0                 100               1.0               log2               5
#
#                                                params  split0_test_score  \
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.037620
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.040361
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.045263
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.034815
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.046526
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 3           -0.024400          -0.007420          -0.032640
# 11          -0.020075          -0.021294          -0.036158
# 8           -0.014727          -0.015395          -0.036394
# 9           -0.024990          -0.021937          -0.047532
# 0           -0.022320          -0.022712          -0.047768
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 3           -0.024807        -0.025377        0.010260                1
# 11          -0.024880        -0.028553        0.008189                2
# 8           -0.039504        -0.030257        0.012731                3
# 9           -0.024327        -0.030720        0.009490                4
# 0           -0.028542        -0.033574        0.011306                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.031
# R2: 0.220
# MSE: 0.027
# MAE: 0.020

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 3D  Pred Target 3D
# 1036 2024-02-08  1403.05    1394.45         1404.99
# 1037 2024-02-09  1403.60    1384.05         1405.42
# 1038 2024-02-12  1390.00    1414.05         1397.46
# 1039 2024-02-13  1394.45    1419.90         1400.51
# 1040 2024-02-14  1384.05    1417.10         1390.59
# 1041 2024-02-15  1414.05    1454.30         1413.90
# 1042 2024-02-16  1419.90    1439.15         1417.67
# 1043 2024-02-19  1417.10    1419.55         1414.87
# 1044 2024-02-20  1454.30    1420.60         1452.97
# 1045 2024-02-21  1439.15    1422.30         1437.37

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (1042, 43)
# y.shape: (1042,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.314068      0.011068         0.044109        0.001671
# 11       0.296377      0.017627         0.043978        0.001168
# 8        0.347106      0.018807         0.042710        0.000586
# 4        0.265757      0.026446         0.034689        0.005876
# 3        0.226297      0.022795         0.035369        0.006966
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                 100              0.75               log2               4
# 11                100              0.75               0.25               4
# 8                 100               1.0               sqrt               4
# 4                  75              0.75               log2               5
# 3                  75               1.0               0.25               4
#
#                                                params  split0_test_score  \
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.021028
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.051373
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.027042
# 4   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.064413
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.027189
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9           -0.075999          -0.046217          -0.119300
# 11          -0.101307          -0.056445          -0.104872
# 8           -0.102422          -0.076779          -0.131414
# 4           -0.110440          -0.076016          -0.120589
# 3           -0.149166          -0.046587          -0.141099
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9           -0.046708        -0.061850        0.033588                1
# 11          -0.063652        -0.075530        0.022866                2
# 8           -0.066854        -0.080902        0.035014                3
# 4           -0.054299        -0.085152        0.025926                4
# 3           -0.072156        -0.087239        0.049441                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.046
# R2: 0.285
# MSE: 0.039
# MAE: 0.029

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 7D  Pred Target 7D
# 1032 2024-02-02  1446.15    1394.45         1440.34
# 1033 2024-02-05  1444.85    1384.05         1433.36
# 1034 2024-02-06  1444.10    1414.05         1432.89
# 1035 2024-02-07  1429.95    1419.90         1426.68
# 1036 2024-02-08  1403.05    1417.10         1408.11
# 1037 2024-02-09  1403.60    1454.30         1407.89
# 1038 2024-02-12  1390.00    1439.15         1391.19
# 1039 2024-02-13  1394.45    1419.55         1398.94
# 1040 2024-02-14  1384.05    1420.60         1393.02
# 1041 2024-02-15  1414.05    1422.30         1407.84

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (1034, 43)
# y.shape: (1034,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 1.0,
#  'max_features': 'sqrt',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.309437      0.026857         0.041742        0.000683
# 0       0.382564      0.070662         0.047246        0.009939
# 9       0.286574      0.002462         0.043276        0.001373
# 3       0.224104      0.003142         0.031210        0.001632
# 4       0.246008      0.012191         0.033298        0.002309
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 8                100               1.0               sqrt               4
# 0                100               1.0               log2               5
# 9                100              0.75               log2               4
# 3                 75               1.0               0.25               4
# 4                 75              0.75               log2               5
#
#                                               params  split0_test_score  \
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.040532
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.014874
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.031235
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.006445
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...           0.026370
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8          -0.197437          -0.285222          -0.311817          -0.158178
# 0          -0.215506          -0.277654          -0.281439          -0.191014
# 9          -0.241635          -0.247271          -0.352181          -0.175167
# 3          -0.260519          -0.268535          -0.347639          -0.207788
# 4          -0.305454          -0.274615          -0.379733          -0.226326
#
#    mean_test_score  std_test_score  rank_test_score
# 8        -0.182424        0.124766                1
# 0        -0.190148        0.108323                2
# 9        -0.197004        0.127412                3
# 3        -0.215607        0.119682                4
# 4        -0.231952        0.138437                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.065
# R2: 0.436
# MSE: 0.049
# MAE: 0.038

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 15D  Pred Target 15D
# 1024 2024-01-20  1478.85     1394.45          1456.39
# 1025 2024-01-23  1427.35     1384.05          1389.60
# 1026 2024-01-24  1455.90     1414.05          1429.46
# 1027 2024-01-25  1434.90     1419.90          1414.65
# 1028 2024-01-29  1454.65     1417.10          1437.05
# 1029 2024-01-30  1444.30     1454.30          1425.68
# 1030 2024-01-31  1462.55     1439.15          1444.31
# 1031 2024-02-01  1466.35     1419.55          1444.75
# 1032 2024-02-02  1446.15     1420.60          1426.70
# 1033 2024-02-05  1444.85     1422.30          1421.56

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (1019, 43)
# y.shape: (1019,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.300340      0.024595         0.041821        0.000520
# 8        0.287435      0.003303         0.043354        0.001848
# 4        0.254899      0.008807         0.031196        0.000623
# 0        0.362978      0.074204         0.047416        0.007967
# 11       0.306517      0.019499         0.041355        0.002984
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                 100              0.75               log2               4
# 8                 100               1.0               sqrt               4
# 4                  75              0.75               log2               5
# 0                 100               1.0               log2               5
# 11                100              0.75               0.25               4
#
#                                                params  split0_test_score  \
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.018913
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.031488
# 4   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.007036
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.017580
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.003033
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9           -0.207718          -0.637816          -0.363467
# 8           -0.293939          -0.674412          -0.374733
# 4           -0.156361          -0.737013          -0.403118
# 0           -0.253744          -0.770939          -0.344493
# 11          -0.296588          -0.818814          -0.277989
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9           -0.219846        -0.289552        0.205695                1
# 8           -0.174264        -0.297172        0.233006                2
# 4           -0.193908        -0.299487        0.252716                3
# 0           -0.201081        -0.317567        0.250561                4
# 11          -0.206912        -0.319454        0.271391                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.089
# R2: 0.545
# MSE: 0.060
# MAE: 0.047

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 30D  Pred Target 30D
# 1009 2024-01-01  1698.10     1394.45          1583.27
# 1010 2024-01-02  1699.10     1384.05          1584.76
# 1011 2024-01-03  1672.90     1414.05          1562.80
# 1012 2024-01-04  1690.85     1419.90          1580.44
# 1013 2024-01-05  1682.20     1417.10          1579.23
# 1014 2024-01-08  1663.45     1454.30          1567.54
# 1015 2024-01-09  1650.50     1439.15          1554.65
# 1016 2024-01-10  1655.95     1419.55          1557.94
# 1017 2024-01-11  1649.00     1420.60          1552.80
# 1018 2024-01-12  1641.20     1422.30          1546.11

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# 52W H                             13.1        7.6         8.1         9.0
# Range 60MA                         4.3        9.9         6.1         8.9
# DayOfYear                          2.8        5.2         9.7         9.9
# PE                                 4.3        6.0         5.3        10.5
# Month                              0.6        3.0         6.7         6.5
# DaysSinceLastTradingSession        0.1        0.4         8.4         7.5
# Close 60MA                         6.6        3.6         3.2         2.2
# VWAP 60MA                          5.2        3.0         3.1         2.2
# 52W L                              0.7        2.6         5.3         4.8
# Range 7MA                          2.7        5.1         3.2         1.8
# Year                               0.1        1.5         4.7         5.5
# Range 30MA                         1.6        2.0         3.2         5.0
# Range 15MA                         1.6        3.4         3.0         3.7
# Close 30MA                         5.9        1.4         2.5         1.5
# VWAP 30MA                          4.7        1.8         2.6         1.7
# Open                               6.2        3.2         0.7         0.2
# Close 15MA                         5.3        2.2         1.8         1.1
# VWAP 15MA                          4.3        2.4         2.1         1.4
# Low                                5.2        2.7         0.9         0.3
# #Trades 60MA                       0.5        2.7         3.9         1.3
# Quarter                            0.6        1.1         1.6         4.8
# VWAP                               4.1        2.5         0.7         0.5
# VWAP 7MA                           3.7        1.6         0.8         1.3
# Volume 60MA                        1.7        3.1         1.7         0.8
# Close 7MA                          3.0        1.6         0.7         1.0
# Value 60MA                         0.8        3.6         1.3         0.6
# #Trades 30MA                       0.5        1.7         2.5         0.7
# High                               1.3        1.7         1.2         0.8
# Day                                1.2        2.2         0.5         0.5
# Value 30MA                         0.7        1.7         0.8         0.6
# LTP                                1.5        1.4         0.2         0.5
# Volume 30MA                        0.8        0.9         0.6         0.5
# Volume 15MA                        0.2        1.7         0.5         0.4
# #Trades 15MA                       0.9        0.5         0.6         0.7
# Value 15MA                         0.2        1.3         0.7         0.4
# Value 7MA                          0.8        1.0         0.5         0.1
# Volume 7MA                         0.9        0.7         0.2         0.3
# #Trades 7MA                        0.4        1.1         0.1         0.2
# Streak                             0.3        0.3         0.0         0.4
# Weekday                            0.2        0.2         0.0         0.1
# Is52WLow                           0.0        0.3         0.1         0.0
# IsGreen                            0.2        0.1         0.0         0.0
# Is52WHigh                          0.0        0.0         0.0         0.0
#
#                              Mean
# 52W H                         9.5
# Range 60MA                    7.3
# DayOfYear                     6.9
# PE                            6.5
# Month                         4.2
# DaysSinceLastTradingSession   4.1
# Close 60MA                    3.9
# VWAP 60MA                     3.4
# 52W L                         3.3
# Range 7MA                     3.2
# Year                          3.0
# Range 30MA                    3.0
# Range 15MA                    2.9
# Close 30MA                    2.8
# VWAP 30MA                     2.7
# Open                          2.6
# Close 15MA                    2.6
# VWAP 15MA                     2.5
# Low                           2.3
# #Trades 60MA                  2.1
# Quarter                       2.0
# VWAP                          2.0
# VWAP 7MA                      1.8
# Volume 60MA                   1.8
# Close 7MA                     1.6
# Value 60MA                    1.6
# #Trades 30MA                  1.3
# High                          1.3
# Day                           1.1
# Value 30MA                    1.0
# LTP                           0.9
# Volume 30MA                   0.7
# Volume 15MA                   0.7
# #Trades 15MA                  0.7
# Value 15MA                    0.6
# Value 7MA                     0.6
# Volume 7MA                    0.5
# #Trades 7MA                   0.5
# Streak                        0.3
# Weekday                       0.1
# Is52WLow                      0.1
# IsGreen                       0.1
# Is52WHigh                     0.0

# %% [markdown]
# ## Forecasts

# %%
stock_data.processed.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-10:, :]
# Out:
#            Date    Close  Pred Target 3D  Pred Target 7D  Pred Target 15D  \
# 1039 2024-02-13  1394.45         1400.51         1398.94          1371.33
# 1040 2024-02-14  1384.05         1390.59         1393.02          1367.27
# 1041 2024-02-15  1414.05         1413.90         1407.84          1387.91
# 1042 2024-02-16  1419.90         1417.67         1411.66          1392.79
# 1043 2024-02-19  1417.10         1414.87         1411.84          1389.13
# 1044 2024-02-20  1454.30         1452.97         1446.76          1423.22
# 1045 2024-02-21  1439.15         1437.37         1432.88          1409.56
# 1046 2024-02-22  1419.55         1418.07         1426.87          1394.43
# 1047 2024-02-23  1420.60         1418.55         1418.62          1392.32
# 1048 2024-02-26  1422.30         1421.12         1422.61          1393.70
#
#       Pred Target 30D
# 1039          1385.14
# 1040          1364.60
# 1041          1404.11
# 1042          1412.51
# 1043          1408.57
# 1044          1433.83
# 1045          1428.34
# 1046          1410.04
# 1047          1414.98
# 1048          1413.89

# %%
latest_preds = stock_data.processed.iloc[-1]
print(f"Date: {latest_preds['Date'].date()}")
print(f"Close: {latest_preds['Close']}")

for pred in expected_errors.keys():
    print(f"{pred}: {latest_preds[pred]} ± {expected_errors[pred] * latest_preds['Close']:.2f}")
# Out:
# Date: 2024-02-26
# Close: 1422.3
# Pred Target 3D: 1421.12 ± 38.84
# Pred Target 7D: 1422.61 ± 55.71
# Pred Target 15D: 1393.7 ± 69.63
# Pred Target 30D: 1413.89 ± 84.92
