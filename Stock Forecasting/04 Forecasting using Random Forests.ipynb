# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

import stock_utils.constants as cnst
import stock_utils.data as sd

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# SCREENER_EPS_DATA_DIR = PosixPath('../data/Screener.in/EPS') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = sd.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['DEEPAKFERT', 'HDFCBANK', 'INDIGOPNTS', 'ITBEES', 'JUBLFOOD', 'NH']

# %%
STOCK_SYMBOL = stock_symbols[1]
STOCK_SYMBOL
# Out:
# 'HDFCBANK'

# %% [markdown]
# ## Loading stock data

# %%
stock_data = sd.StockData(STOCK_SYMBOL)
stock_data
# Out:
# Symbol: HDFCBANK
# Total records: 1097
# First record: 2020-01-01
# Last record: 2024-05-09

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = stock_data.standardized.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
stock_data.standardized[target_cols].describe()
# Out:
#          Target 3D    Target 7D   Target 15D   Target 30D
# count  1094.000000  1090.000000  1082.000000  1067.000000
# mean      1.000856     1.002144     1.004490     1.009055
# std       0.030511     0.045680     0.064045     0.087293
# min       0.820000     0.718000     0.668000     0.629000
# 25%       0.986000     0.978000     0.968250     0.961000
# 50%       1.000000     1.002000     1.003500     1.008000
# 75%       1.016000     1.025000     1.041750     1.057000
# max       1.178000     1.219000     1.231000     1.322000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = stock_data.standardized[
        stock_data.standardized[target_col].notnull()
    ].drop(columns = target_cols).copy()
    y = stock_data.standardized[
        stock_data.standardized[target_col].notnull()
    ][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = stock_data.standardized.drop(columns = target_cols).columns.to_list()
)

expected_errors = {}

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 12,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(y, preds):
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {root_mean_squared_error(y, preds):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

def expected_error(y, preds):
    return root_mean_squared_error(y, preds)

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (1094, 43)
# y.shape: (1094,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.277629      0.035036         0.062300        0.017133
# 8        0.276722      0.019009         0.051737        0.006350
# 11       0.249389      0.019759         0.046124        0.004891
# 0        0.309388      0.055052         0.054712        0.006897
# 4        0.205800      0.020833         0.037303        0.004884
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                 100              0.75               log2               4
# 8                 100               1.0               sqrt               4
# 11                100              0.75               0.25               4
# 0                 100               1.0               log2               5
# 4                  75              0.75               log2               5
#
#                                                params  split0_test_score  \
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.009058
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.019188
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.030489
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.055402
# 4   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.022251
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9           -0.025443          -0.004481          -0.011058
# 8           -0.014869          -0.015400          -0.011873
# 11          -0.024542          -0.015106          -0.016061
# 0           -0.010189          -0.016950          -0.013060
# 4           -0.032574          -0.017783          -0.014485
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9            0.007005        -0.008607        0.010492                1
# 8           -0.001954        -0.012657        0.005835                2
# 11           0.001096        -0.017020        0.010684                3
# 0            0.005021        -0.018116        0.020077                4
# 4           -0.014931        -0.020405        0.006684                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.031
# R2: 0.201
# MSE: 0.027
# MAE: 0.020

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 3D  Pred Target 3D
# 1084 2024-04-22  1512.20    1510.75         1512.36
# 1085 2024-04-23  1507.60    1509.80         1507.52
# 1086 2024-04-24  1511.70    1529.50         1511.44
# 1087 2024-04-25  1510.75    1520.10         1511.49
# 1088 2024-04-26  1509.80    1532.25         1510.61
# 1089 2024-04-29  1529.50    1519.60         1531.24
# 1090 2024-04-30  1520.10    1522.65         1521.66
# 1091 2024-05-02  1532.25    1506.15         1532.74
# 1092 2024-05-03  1519.60    1482.65         1519.86
# 1093 2024-05-06  1522.65    1447.50         1522.80

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (1090, 43)
# y.shape: (1090,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.246277      0.020449         0.046189        0.003061
# 4        0.189452      0.007182         0.039229        0.004530
# 8        0.303106      0.034815         0.052529        0.006353
# 0        0.315822      0.031487         0.055271        0.008454
# 10       0.357625      0.018627         0.065274        0.009511
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                 100              0.75               log2               4
# 4                  75              0.75               log2               5
# 8                 100               1.0               sqrt               4
# 0                 100               1.0               log2               5
# 10                125               1.0               log2               6
#
#                                                params  split0_test_score  \
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.037433
# 4   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.045455
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.066876
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.042799
# 10  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.038974
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9           -0.095369          -0.028301          -0.027939
# 4           -0.099527          -0.053043          -0.030762
# 8           -0.131874          -0.047498          -0.030493
# 0           -0.156294          -0.044024          -0.027170
# 10          -0.166789          -0.079284          -0.048563
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9            0.032941        -0.031220        0.040717                1
# 4            0.024189        -0.040919        0.039861                2
# 8            0.027253        -0.049897        0.051658                3
# 0            0.020324        -0.049993        0.058056                4
# 10           0.043493        -0.058024        0.067882                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.046
# R2: 0.279
# MSE: 0.039
# MAE: 0.028

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 7D  Pred Target 7D
# 1080 2024-04-15  1494.70    1510.75         1495.24
# 1081 2024-04-16  1509.25    1509.80         1508.35
# 1082 2024-04-18  1494.70    1529.50         1496.19
# 1083 2024-04-19  1531.30    1520.10         1530.38
# 1084 2024-04-22  1512.20    1532.25         1514.64
# 1085 2024-04-23  1507.60    1519.60         1509.99
# 1086 2024-04-24  1511.70    1522.65         1516.06
# 1087 2024-04-25  1510.75    1506.15         1514.21
# 1088 2024-04-26  1509.80    1482.65         1512.94
# 1089 2024-04-29  1529.50    1447.50         1530.63

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (1082, 43)
# y.shape: (1082,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.241323      0.026083         0.045781        0.004514
# 11       0.303201      0.034938         0.057710        0.009238
# 7        0.191279      0.010649         0.038866        0.005250
# 3        0.192592      0.009971         0.039279        0.005763
# 0        0.297733      0.031331         0.055163        0.005133
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                 100              0.75               log2               4
# 11                100              0.75               0.25               4
# 7                  75              0.75               0.25               5
# 3                  75               1.0               0.25               4
# 0                 100               1.0               log2               5
#
#                                                params  split0_test_score  \
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.018736
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.041046
# 7   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.084604
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.086553
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.078499
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 9           -0.163683          -0.131792          -0.102372
# 11          -0.170329          -0.161971          -0.111912
# 7           -0.132202          -0.201168          -0.083860
# 3           -0.199231          -0.130295          -0.125827
# 0           -0.163983          -0.174112          -0.095494
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 9           -0.018999        -0.087117        0.059003                1
# 11          -0.013360        -0.099724        0.063103                2
# 7           -0.008456        -0.102058        0.063448                3
# 3            0.028724        -0.102636        0.075030                4
# 0           -0.003180        -0.103054        0.062284                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.064
# R2: 0.403
# MSE: 0.049
# MAE: 0.038

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 15D  Pred Target 15D
# 1072 2024-04-02  1480.15     1510.75          1479.49
# 1073 2024-04-03  1482.30     1509.80          1482.29
# 1074 2024-04-04  1527.60     1529.50          1518.08
# 1075 2024-04-05  1549.55     1520.10          1542.97
# 1076 2024-04-08  1546.60     1532.25          1535.94
# 1077 2024-04-09  1548.55     1519.60          1539.62
# 1078 2024-04-10  1536.35     1522.65          1528.43
# 1079 2024-04-12  1518.95     1506.15          1514.38
# 1080 2024-04-15  1494.70     1482.65          1498.15
# 1081 2024-04-16  1509.25     1447.50          1505.04

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (1067, 43)
# y.shape: (1067,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 75, 'max_samples': 1.0, 'max_features': 0.25, 'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 3        0.210057      0.042465         0.040489        0.006796
# 0        0.307032      0.036120         0.056592        0.001975
# 8        0.297456      0.026342         0.066665        0.023174
# 11       0.261441      0.013080         0.049955        0.005932
# 9        0.305468      0.013924         0.056513        0.006402
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 3                  75               1.0               0.25               4
# 0                 100               1.0               log2               5
# 8                 100               1.0               sqrt               4
# 11                100              0.75               0.25               4
# 9                 100              0.75               log2               4
#
#                                                params  split0_test_score  \
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.023580
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.059328
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.034604
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.022510
# 9   {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.002042
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 3            0.096147          -0.653056          -0.162674
# 0            0.152382          -0.726041          -0.142814
# 8            0.080620          -0.565580          -0.194075
# 11           0.058691          -0.649658          -0.175010
# 9            0.040183          -0.539293          -0.193481
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 3            0.013155        -0.136570        0.271905                1
# 0           -0.035960        -0.138621        0.309672                2
# 8           -0.049519        -0.138790        0.232973                3
# 11           0.007943        -0.147105        0.264007                4
# 9           -0.055944        -0.149299        0.210509                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.087
# R2: 0.625
# MSE: 0.053
# MAE: 0.043

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_data.processed[pred_col_name] = (
    model.predict(
        stock_data.standardized.drop(columns = target_cols)
    ) * stock_data.processed['Close']
).round(2)
stock_data.processed[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 30D  Pred Target 30D
# 1057 2024-03-07  1446.10     1510.75          1479.34
# 1058 2024-03-11  1427.80     1509.80          1460.06
# 1059 2024-03-12  1459.55     1529.50          1480.41
# 1060 2024-03-13  1460.40     1520.10          1487.19
# 1061 2024-03-14  1455.45     1532.25          1483.79
# 1062 2024-03-15  1452.65     1519.60          1473.63
# 1063 2024-03-18  1446.05     1522.65          1476.20
# 1064 2024-03-19  1449.35     1506.15          1476.73
# 1065 2024-03-20  1431.05     1482.65          1456.67
# 1066 2024-03-21  1445.75     1447.50          1465.97

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# 52W H                              7.1        9.4        10.1        13.6
# Range 60MA                         5.3        9.9         5.7        10.8
# PE                                 3.5        5.3         6.9        11.8
# DayOfYear                          1.6        4.9         7.4        11.9
# DaysSinceLastTradingSession        0.2        0.4         9.6         7.9
# VWAP 60MA                          6.4        3.1         2.2         2.7
# Range 7MA                          4.4        5.4         2.4         2.0
# Range 15MA                         2.6        3.4         4.0         4.1
# Close 60MA                         5.0        3.4         3.0         2.6
# Month                              0.5        2.0         5.2         5.8
# 52W L                              1.5        2.2         3.9         5.0
# Close 30MA                         6.2        1.6         2.5         1.9
# Range 30MA                         1.5        2.2         3.3         4.7
# VWAP 15MA                          5.4        2.7         1.9         0.9
# Year                               0.4        1.1         3.0         5.3
# Close 15MA                         4.7        1.6         2.2         1.0
# VWAP 30MA                          5.2        1.4         1.3         1.0
# VWAP 7MA                           4.1        2.0         1.4         0.5
# Volume 60MA                        2.1        3.6         1.8         0.2
# VWAP                               4.3        2.6         0.6         0.0
# #Trades 60MA                       0.8        2.7         3.6         0.5
# Low                                3.9        2.2         0.7         0.2
# Open                               2.6        3.2         0.9         0.2
# Close 7MA                          3.8        1.8         1.1         0.3
# Value 60MA                         2.0        3.2         1.3         0.1
# #Trades 30MA                       0.9        2.1         2.8         0.6
# Day                                1.2        2.8         1.6         0.1
# High                               2.1        2.0         1.2         0.3
# Quarter                            0.5        0.9         1.3         2.4
# Value 30MA                         0.8        1.6         1.5         0.2
# Volume 30MA                        1.0        0.7         1.7         0.2
# #Trades 15MA                       1.2        0.8         1.3         0.2
# LTP                                1.8        1.3         0.2         0.2
# Value 15MA                         0.8        1.5         0.2         0.2
# Volume 15MA                        0.7        1.3         0.6         0.1
# Value 7MA                          1.0        1.1         0.4         0.1
# Volume 7MA                         1.2        0.5         0.3         0.2
# #Trades 7MA                        0.6        0.7         0.5         0.1
# Streak                             0.5        0.3         0.0         0.1
# Is52WLow                           0.3        0.4         0.0         0.0
# Weekday                            0.2        0.3         0.1         0.1
# IsGreen                            0.1        0.1         0.0         0.0
# Is52WHigh                          0.0        0.0         0.0         0.0
#
#                              Mean
# 52W H                        10.1
# Range 60MA                    7.9
# PE                            6.9
# DayOfYear                     6.5
# DaysSinceLastTradingSession   4.5
# VWAP 60MA                     3.6
# Range 7MA                     3.6
# Range 15MA                    3.5
# Close 60MA                    3.5
# Month                         3.4
# 52W L                         3.2
# Close 30MA                    3.0
# Range 30MA                    2.9
# VWAP 15MA                     2.7
# Year                          2.5
# Close 15MA                    2.4
# VWAP 30MA                     2.2
# VWAP 7MA                      2.0
# Volume 60MA                   1.9
# VWAP                          1.9
# #Trades 60MA                  1.9
# Low                           1.8
# Open                          1.7
# Close 7MA                     1.7
# Value 60MA                    1.7
# #Trades 30MA                  1.6
# Day                           1.4
# High                          1.4
# Quarter                       1.3
# Value 30MA                    1.0
# Volume 30MA                   0.9
# #Trades 15MA                  0.9
# LTP                           0.9
# Value 15MA                    0.7
# Volume 15MA                   0.7
# Value 7MA                     0.6
# Volume 7MA                    0.6
# #Trades 7MA                   0.5
# Streak                        0.2
# Is52WLow                      0.2
# Weekday                       0.2
# IsGreen                       0.1
# Is52WHigh                     0.0

# %% [markdown]
# ## Forecasts

# %%
stock_data.processed.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-10:, :]
# Out:
#            Date    Close  Pred Target 3D  Pred Target 7D  Pred Target 15D  \
# 1087 2024-04-25  1510.75         1511.49         1514.21          1504.91
# 1088 2024-04-26  1509.80         1510.61         1512.94          1503.74
# 1089 2024-04-29  1529.50         1531.24         1530.63          1522.41
# 1090 2024-04-30  1520.10         1521.66         1521.95          1515.11
# 1091 2024-05-02  1532.25         1532.74         1530.68          1525.94
# 1092 2024-05-03  1519.60         1519.86         1519.30          1520.04
# 1093 2024-05-06  1522.65         1522.80         1522.17          1527.94
# 1094 2024-05-07  1506.15         1506.62         1507.44          1522.69
# 1095 2024-05-08  1482.65         1483.50         1485.51          1507.00
# 1096 2024-05-09  1447.50         1448.30         1457.39          1479.56
#
#       Pred Target 30D
# 1087          1529.50
# 1088          1531.43
# 1089          1521.52
# 1090          1520.84
# 1091          1528.06
# 1092          1532.36
# 1093          1528.00
# 1094          1551.91
# 1095          1545.83
# 1096          1514.72

# %%
latest_preds = stock_data.processed.iloc[-1]
print(f"Date: {latest_preds['Date'].date()}")
print(f"Close: {latest_preds['Close']}")

for pred in expected_errors.keys():
    print(f"{pred}: {latest_preds[pred]} ± {expected_errors[pred] * latest_preds['Close']:.2f}")
# Out:
# Date: 2024-05-09
# Close: 1447.5
# Pred Target 3D: 1448.3 ± 39.46
# Pred Target 7D: 1457.39 ± 56.11
# Pred Target 15D: 1479.56 ± 71.60
# Pred Target 30D: 1514.72 ± 77.36
