# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import constants as cnst
import stock_utils as su

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = su.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['HDFCBANK', 'ITBEES']

# %%
STOCK_SYMBOL = stock_symbols[0]
STOCK_SYMBOL
# Out:
# 'HDFCBANK'

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Stock data

# %%
stock_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-processed.parquet')
)

stock_df
# Out:
#            Date     Open     High      Low      LTP    Close     VWAP   52W H  \
# 0    2020-01-01  1276.10  1280.00  1270.60  1279.00  1278.60  1276.64  2503.3
# 1    2020-01-02  1279.00  1288.00  1279.00  1286.00  1286.75  1284.56  2503.3
# 2    2020-01-03  1282.20  1285.00  1263.60  1268.50  1268.40  1270.48  2503.3
# 3    2020-01-06  1260.00  1261.80  1236.00  1240.25  1240.95  1247.24  2503.3
# 4    2020-01-07  1258.90  1271.45  1252.25  1261.00  1260.60  1261.48  2503.3
# ...         ...      ...      ...      ...      ...      ...      ...     ...
# 1020 2024-01-16  1673.00  1683.65  1658.10  1678.00  1679.15  1672.44  1757.5
# 1021 2024-01-17  1570.00  1596.80  1528.40  1542.15  1537.50  1565.65  1757.5
# 1022 2024-01-18  1494.00  1515.00  1480.05  1490.00  1486.15  1495.03  1757.5
# 1023 2024-01-19  1505.95  1510.25  1468.40  1474.90  1470.65  1483.88  1757.5
# 1024 2024-01-20  1483.20  1495.70  1476.00  1480.65  1478.85  1483.92  1757.5
#
#         52W L    Volume         Value  #Trades  Range  IsGreen  Is52WLow  \
# 0     1084.00   1836849  2.345001e+09    46625   9.40        1         0
# 1     1084.00   3068583  3.941792e+09   104570   9.00        1         0
# 2     1084.00   5427775  6.895886e+09   157066  21.40        0         0
# 3     1084.00   5445093  6.791348e+09   155007  25.80        0         0
# 4     1084.00   7362247  9.287302e+09   189026  19.20        1         0
# ...       ...       ...           ...      ...    ...      ...       ...
# 1020  1460.25  12661250  2.117514e+10   347404  25.55        1         0
# 1021  1460.25  85072618  1.331936e+11  2098772  68.40        0         0
# 1022  1460.25  80535465  1.204027e+11  1582497  34.95        0         0
# 1023  1460.25  54800269  8.131686e+10  1275220  41.85        0         0
# 1024  1460.25  12920293  1.917264e+10   403196  19.70        0         0
#
#       Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0             0    1      1  2020        2          1        1
# 1             0    2      1  2020        3          2        1
# 2             0    3      1  2020        4          3        1
# 3             0    6      1  2020        0          6        1
# 4             0    7      1  2020        1          7        1
# ...         ...  ...    ...   ...      ...        ...      ...
# 1020          0   16      1  2024        1         16        1
# 1021          0   17      1  2024        2         17        1
# 1022          0   18      1  2024        3         18        1
# 1023          0   19      1  2024        4         19        1
# 1024          0   20      1  2024        5         20        1
#
#       DaysSinceLastTradingSession  Close 7MA  Close 15MA  Close 30MA  \
# 0                               1    1278.60     1278.60     1278.60
# 1                               1    1282.68     1282.68     1282.68
# 2                               1    1277.92     1277.92     1277.92
# 3                               3    1268.68     1268.68     1268.68
# 4                               1    1267.06     1267.06     1267.06
# ...                           ...        ...         ...         ...
# 1020                            1    1658.86     1678.20     1664.56
# 1021                            1    1640.87     1667.15     1661.69
# 1022                            1    1617.39     1652.54     1656.97
# 1023                            1    1590.92     1636.63     1651.64
# 1024                            1    1566.61     1622.02     1645.83
#
#       Close 60MA  Range 7MA  Range 15MA  Range 30MA  Range 60MA  VWAP 7MA  \
# 0        1278.60       9.40        9.40        9.40        9.40   1276.64
# 1        1282.68       9.20        9.20        9.20        9.20   1280.60
# 2        1277.92      13.27       13.27       13.27       13.27   1277.23
# 3        1268.68      16.40       16.40       16.40       16.40   1269.73
# 4        1267.06      16.96       16.96       16.96       16.96   1268.08
# ...          ...        ...         ...         ...         ...       ...
# 1020     1585.82      25.30       24.76       22.80       20.58   1660.48
# 1021     1586.06      31.88       27.46       24.33       21.35   1645.31
# 1022     1585.73      32.44       28.49       24.77       21.46   1621.62
# 1023     1585.30      35.76       30.02       25.57       21.63   1597.43
# 1024     1585.56      35.74       30.19       25.41       21.43   1573.23
#
#       VWAP 15MA  VWAP 30MA  VWAP 60MA  Volume 7MA  Volume 15MA  Volume 30MA  \
# 0       1276.64    1276.64    1276.64     1836849      1836849      1836849
# 1       1280.60    1280.60    1280.60     2452716      2452716      2452716
# 2       1277.23    1277.23    1277.23     3444402      3444402      3444402
# 3       1269.73    1269.73    1269.73     3944575      3944575      3944575
# 4       1268.08    1268.08    1268.08     4628109      4628109      4628109
# ...         ...        ...        ...         ...          ...          ...
# 1020    1678.64    1664.72    1585.57    10797971     12592121     16089685
# 1021    1669.96    1662.71    1586.34    21665597     17363326     18054925
# 1022    1655.54    1658.30    1585.93    31361600     21263141     20095890
# 1023    1640.64    1653.48    1585.56    38039080     24082779     21581725
# 1024    1626.13    1647.98    1585.80    38576692     24469475     21450268
#
#       Volume 60MA    Value 7MA   Value 15MA   Value 30MA   Value 60MA  \
# 0         1836849   2345000988   2345000988   2345000988   2345000988
# 1         2452716   3143396262   3143396262   3143396262   3143396262
# 2         3444402   4394226092   4394226092   4394226092   4394226092
# 3         3944575   4993506527   4993506527   4993506527   4993506527
# 4         4628109   5852265530   5852265530   5852265530   5852265530
# ...           ...          ...          ...          ...          ...
# 1020     15332293  17939626497  21173698410  26756826044  24372218817
# 1021     16574386  34817957164  28526480964  29781095464  26325036311
# 1022     17730176  49013774376  34039123030  32747198969  28048301982
# 1023     18407581  58727408569  38036670502  34902710598  29048300599
# 1024     18159904  59303603726  38507208419  34614884567  28687419886
#
#       #Trades 7MA  #Trades 15MA  #Trades 30MA  #Trades 60MA  Target 3D  \
# 0           46625         46625         46625         46625    1240.95
# 1           75597         75597         75597         75597    1260.60
# 2          102753        102753        102753        102753    1257.30
# 3          115817        115817        115817        115817    1271.40
# 4          130458        130458        130458        130458    1282.70
# ...           ...           ...           ...           ...        ...
# 1020       297593        324871        336519        323849    1470.65
# 1021       544785        443365        393241        354372    1478.85
# 1022       732341        520660        434624        376597        NaN
# 1023       889730        588066        469801        391650        NaN
# 1024       914362        597722        470835        387968        NaN
#
#       Target 7D  Target 15D  Target 30D
# 0       1282.70     1240.85     1240.60
# 1       1286.00     1244.85     1249.00
# 2       1289.50     1244.55     1241.40
# 3       1284.25     1213.20     1219.35
# 4       1287.65     1223.20     1217.15
# ...         ...         ...         ...
# 1020        NaN         NaN         NaN
# 1021        NaN         NaN         NaN
# 1022        NaN         NaN         NaN
# 1023        NaN         NaN         NaN
# 1024        NaN         NaN         NaN
#
# [1025 rows x 51 columns]

# %% [markdown]
# ### Standardized data

# %%
standardized_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-standardized.parquet')
)

standardized_df
# Out:
#        Open   High    Low    LTP   VWAP  52W H  52W L  IsGreen  Is52WLow  \
# 0     0.998  1.001  0.994  1.000  0.998  1.958  0.848        1         0
# 1     0.994  1.001  0.994  0.999  0.998  1.945  0.842        1         0
# 2     1.011  1.013  0.996  1.000  1.002  1.974  0.855        0         0
# 3     1.015  1.017  0.996  0.999  1.005  2.017  0.874        0         0
# 4     0.999  1.009  0.993  1.000  1.001  1.986  0.860        1         0
# ...     ...    ...    ...    ...    ...    ...    ...      ...       ...
# 1020  0.996  1.003  0.987  0.999  0.996  1.047  0.870        1         0
# 1021  1.021  1.039  0.994  1.003  1.018  1.143  0.950        0         0
# 1022  1.005  1.019  0.996  1.003  1.006  1.183  0.983        0         0
# 1023  1.024  1.027  0.998  1.003  1.009  1.195  0.993        0         0
# 1024  1.003  1.011  0.998  1.001  1.003  1.188  0.987        0         0
#
#       Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0             0    1      1  2020        2          1        1
# 1             0    2      1  2020        3          2        1
# 2             0    3      1  2020        4          3        1
# 3             0    6      1  2020        0          6        1
# 4             0    7      1  2020        1          7        1
# ...         ...  ...    ...   ...      ...        ...      ...
# 1020          0   16      1  2024        1         16        1
# 1021          0   17      1  2024        2         17        1
# 1022          0   18      1  2024        3         18        1
# 1023          0   19      1  2024        4         19        1
# 1024          0   20      1  2024        5         20        1
#
#       DaysSinceLastTradingSession  Close 7MA  Close 15MA  Close 30MA  \
# 0                               1      1.000       1.000       1.000
# 1                               1      0.997       0.997       0.997
# 2                               1      1.008       1.008       1.008
# 3                               3      1.022       1.022       1.022
# 4                               1      1.005       1.005       1.005
# ...                           ...        ...         ...         ...
# 1020                            1      0.988       0.999       0.991
# 1021                            1      1.067       1.084       1.081
# 1022                            1      1.088       1.112       1.115
# 1023                            1      1.082       1.113       1.123
# 1024                            1      1.059       1.097       1.113
#
#       Close 60MA  Range 7MA  Range 15MA  Range 30MA  Range 60MA  VWAP 7MA  \
# 0          1.000      0.007       0.007       0.007       0.007     0.998
# 1          0.997      0.007       0.007       0.007       0.007     0.995
# 2          1.008      0.010       0.010       0.010       0.010     1.007
# 3          1.022      0.013       0.013       0.013       0.013     1.023
# 4          1.005      0.013       0.013       0.013       0.013     1.006
# ...          ...        ...         ...         ...         ...       ...
# 1020       0.944      0.015       0.015       0.014       0.012     0.989
# 1021       1.032      0.021       0.018       0.016       0.014     1.070
# 1022       1.067      0.022       0.019       0.017       0.014     1.091
# 1023       1.078      0.024       0.020       0.017       0.015     1.086
# 1024       1.072      0.024       0.020       0.017       0.014     1.064
#
#       VWAP 15MA  VWAP 30MA  VWAP 60MA  Volume 7MA  Volume 15MA  Volume 30MA  \
# 0         0.998      0.998      0.998       1.000        1.000        1.000
# 1         0.995      0.995      0.995       0.799        0.799        0.799
# 2         1.007      1.007      1.007       0.635        0.635        0.635
# 3         1.023      1.023      1.023       0.724        0.724        0.724
# 4         1.006      1.006      1.006       0.629        0.629        0.629
# ...         ...        ...        ...         ...          ...          ...
# 1020      1.000      0.991      0.944       0.853        0.995        1.271
# 1021      1.086      1.081      1.032       0.255        0.204        0.212
# 1022      1.114      1.116      1.067       0.389        0.264        0.250
# 1023      1.116      1.124      1.078       0.694        0.439        0.394
# 1024      1.100      1.114      1.072       2.986        1.894        1.660
#
#       Volume 60MA  Value 7MA  Value 15MA  Value 30MA  Value 60MA  #Trades 7MA  \
# 0           1.000      1.000       1.000       1.000       1.000        1.000
# 1           0.799      0.797       0.797       0.797       0.797        0.723
# 2           0.635      0.637       0.637       0.637       0.637        0.654
# 3           0.724      0.735       0.735       0.735       0.735        0.747
# 4           0.629      0.630       0.630       0.630       0.630        0.690
# ...           ...        ...         ...         ...         ...          ...
# 1020        1.211      0.847       1.000       1.264       1.151        0.857
# 1021        0.195      0.261       0.214       0.224       0.198        0.260
# 1022        0.220      0.407       0.283       0.272       0.233        0.463
# 1023        0.336      0.722       0.468       0.429       0.357        0.698
# 1024        1.406      3.093       2.008       1.805       1.496        2.268
#
#       #Trades 15MA  #Trades 30MA  #Trades 60MA  Target 3D  Target 7D  \
# 0            1.000         1.000         1.000      0.971      1.003
# 1            0.723         0.723         0.723      0.980      0.999
# 2            0.654         0.654         0.654      0.991      1.017
# 3            0.747         0.747         0.747      1.025      1.035
# 4            0.690         0.690         0.690      1.018      1.021
# ...            ...           ...           ...        ...        ...
# 1020         0.935         0.969         0.932      0.876        NaN
# 1021         0.211         0.187         0.169      0.962        NaN
# 1022         0.329         0.275         0.238        NaN        NaN
# 1023         0.461         0.368         0.307        NaN        NaN
# 1024         1.482         1.168         0.962        NaN        NaN
#
#       Target 15D  Target 30D
# 0          0.970       0.970
# 1          0.967       0.971
# 2          0.981       0.979
# 3          0.978       0.983
# 4          0.970       0.966
# ...          ...         ...
# 1020         NaN         NaN
# 1021         NaN         NaN
# 1022         NaN         NaN
# 1023         NaN         NaN
# 1024         NaN         NaN
#
# [1025 rows x 45 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = standardized_df.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
standardized_df[target_cols].describe()
# Out:
#          Target 3D    Target 7D   Target 15D  Target 30D
# count  1022.000000  1018.000000  1010.000000  995.000000
# mean      1.000904     1.002511     1.005721    1.012089
# std       0.031153     0.046105     0.064164    0.086329
# min       0.820000     0.718000     0.668000    0.629000
# 25%       0.985000     0.978000     0.968000    0.963000
# 50%       1.000000     1.002000     1.003000    1.009000
# 75%       1.016750     1.026000     1.043000    1.060000
# max       1.178000     1.219000     1.231000    1.322000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = standardized_df[standardized_df[target_col].notnull()].drop(columns = target_cols).copy()
    y = standardized_df[standardized_df[target_col].notnull()][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = standardized_df.drop(columns = target_cols).columns.to_list()
)

expected_errors = {}

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 10,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(y, preds):
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {mean_squared_error(y, preds, squared = False):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

def expected_error(y, preds):
    return mean_squared_error(y, preds, squared = False)

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (1022, 41)
# y.shape: (1022,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.370955      0.017420         0.045594        0.001901
# 8       0.368575      0.022287         0.046923        0.003967
# 0       0.541190      0.047691         0.064040        0.005567
# 4       0.313265      0.028186         0.041903        0.005304
# 5       0.562382      0.056410         0.066554        0.013919
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 8                100               1.0               sqrt               4
# 0                100               1.0               log2               5
# 4                 75              0.75               log2               5
# 5                125               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.029775
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.027244
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.037833
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.046225
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.028307
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.016731          -0.025116           0.002177           0.018198
# 8          -0.024496          -0.023780          -0.001474           0.012458
# 0          -0.030381          -0.030807          -0.003433           0.015476
# 4          -0.023832          -0.028429          -0.010089           0.009387
# 5          -0.027365          -0.046113          -0.006985           0.009080
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.010249        0.017933                1
# 8        -0.012907        0.015698                2
# 0        -0.017395        0.020207                3
# 4        -0.019838        0.018629                4
# 5        -0.019938        0.019080                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.031
# R2: 0.207
# MSE: 0.028
# MAE: 0.020

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 3D  Pred Target 3D
# 1012 2024-01-04  1690.85    1650.50         1685.01
# 1013 2024-01-05  1682.20    1655.95         1674.88
# 1014 2024-01-08  1663.45    1649.00         1654.91
# 1015 2024-01-09  1650.50    1641.20         1644.65
# 1016 2024-01-10  1655.95    1672.80         1648.96
# 1017 2024-01-11  1649.00    1679.15         1643.94
# 1018 2024-01-12  1641.20    1537.50         1635.47
# 1019 2024-01-15  1672.80    1486.15         1660.21
# 1020 2024-01-16  1679.15    1470.65         1668.12
# 1021 2024-01-17  1537.50    1478.85         1519.49

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (1018, 41)
# y.shape: (1018,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.391771      0.023002         0.045184        0.003455
# 8       0.406806      0.019437         0.052271        0.006312
# 3       0.279092      0.017810         0.040632        0.003763
# 4       0.379976      0.054883         0.049706        0.009212
# 1       0.324952      0.022019         0.044632        0.000953
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 8                100               1.0               sqrt               4
# 3                 75               1.0               0.25               4
# 4                 75              0.75               log2               5
# 1                 75               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.044130
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.070306
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.077212
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.093062
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.104088
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.077612          -0.149349           0.009914          -0.031395
# 8          -0.069298          -0.128129           0.000695          -0.032475
# 3          -0.088351          -0.169286           0.022966          -0.015896
# 4          -0.096707          -0.138941           0.004018          -0.066147
# 1          -0.101219          -0.146563           0.010935          -0.050445
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.058515        0.053368                1
# 8        -0.059903        0.043071                2
# 3        -0.065556        0.065906                3
# 4        -0.078168        0.047239                4
# 1        -0.078276        0.054017                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.046
# R2: 0.275
# MSE: 0.039
# MAE: 0.029

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 7D  Pred Target 7D
# 1008 2023-12-29  1709.25    1650.50         1714.72
# 1009 2024-01-01  1698.10    1655.95         1684.87
# 1010 2024-01-02  1699.10    1649.00         1689.64
# 1011 2024-01-03  1672.90    1641.20         1663.53
# 1012 2024-01-04  1690.85    1672.80         1682.50
# 1013 2024-01-05  1682.20    1679.15         1674.77
# 1014 2024-01-08  1663.45    1537.50         1644.30
# 1015 2024-01-09  1650.50    1486.15         1635.05
# 1016 2024-01-10  1655.95    1470.65         1634.63
# 1017 2024-01-11  1649.00    1478.85         1629.75

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (1010, 41)
# y.shape: (1010,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.380012      0.032854         0.045434        0.001819
# 8       0.382554      0.052639         0.051270        0.005999
# 5       0.507095      0.027720         0.058401        0.005171
# 1       0.329078      0.011327         0.045562        0.002065
# 4       0.297595      0.014836         0.044537        0.005777
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 8                100               1.0               sqrt               4
# 5                125               1.0               sqrt               5
# 1                 75               1.0               sqrt               5
# 4                 75              0.75               log2               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.149794
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.140925
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.196576
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.181165
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.203130
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.126462          -0.227065           0.019661          -0.296189
# 8          -0.172908          -0.251921           0.031193          -0.249980
# 5          -0.183304          -0.287463          -0.009229          -0.258648
# 1          -0.173820          -0.308994          -0.007704          -0.275462
# 4          -0.167687          -0.311213           0.013520          -0.323950
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.155970        0.106274                1
# 8        -0.156908        0.103521                2
# 5        -0.187044        0.096886                3
# 1        -0.189429        0.104913                4
# 4        -0.198492        0.121955                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.064
# R2: 0.394
# MSE: 0.050
# MAE: 0.039

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 15D  Pred Target 15D
# 1000 2023-12-18  1655.70     1650.50          1664.29
# 1001 2023-12-19  1652.90     1655.95          1659.89
# 1002 2023-12-20  1657.00     1649.00          1662.36
# 1003 2023-12-21  1686.70     1641.20          1691.51
# 1004 2023-12-22  1670.85     1672.80          1676.92
# 1005 2023-12-26  1682.45     1679.15          1690.65
# 1006 2023-12-27  1703.30     1537.50          1708.89
# 1007 2023-12-28  1705.25     1486.15          1712.20
# 1008 2023-12-29  1709.25     1470.65          1715.40
# 1009 2024-01-01  1698.10     1478.85          1673.27

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (995, 41)
# y.shape: (995,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 1.0,
#  'max_features': 'sqrt',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.372271      0.013669         0.045414        0.001899
# 9       0.350192      0.012828         0.048206        0.003916
# 4       0.303377      0.037290         0.043841        0.005868
# 0       0.495822      0.083831         0.063319        0.019661
# 5       0.487665      0.027817         0.056943        0.004579
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 8                100               1.0               sqrt               4
# 9                100              0.75               log2               4
# 4                 75              0.75               log2               5
# 0                100               1.0               log2               5
# 5                125               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.354177
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.298608
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.368166
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.304180
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.443828
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8          -0.096145          -0.643364           0.038969          -0.321205
# 9          -0.072442          -0.696006           0.002033          -0.359565
# 4          -0.075456          -0.788485           0.017922          -0.374612
# 0          -0.099664          -0.871815          -0.013129          -0.361173
# 5          -0.101359          -0.870700           0.040003          -0.463088
#
#    mean_test_score  std_test_score  rank_test_score
# 8        -0.275184        0.234376                1
# 9        -0.284917        0.245862                2
# 4        -0.317759        0.282400                3
# 0        -0.329992        0.299554                4
# 5        -0.367794        0.317825                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.086
# R2: 0.560
# MSE: 0.057
# MAE: 0.045

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#           Date    Close  Target 30D  Pred Target 30D
# 985 2023-11-24  1532.10     1650.50          1573.98
# 986 2023-11-28  1528.65     1655.95          1576.27
# 987 2023-11-29  1559.15     1649.00          1592.13
# 988 2023-11-30  1558.80     1641.20          1578.88
# 989 2023-12-01  1555.40     1672.80          1586.40
# 990 2023-12-04  1609.40     1679.15          1622.73
# 991 2023-12-05  1623.70     1537.50          1632.21
# 992 2023-12-06  1627.80     1486.15          1635.71
# 993 2023-12-07  1630.45     1470.65          1640.16
# 994 2023-12-08  1653.20     1478.85          1665.37

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# 52W H                              7.0        6.4         9.0        10.4
# Range 60MA                         5.1       10.3         5.1         9.1
# DayOfYear                          2.4        5.0         7.6        12.9
# Month                              1.7        2.7         6.4         9.1
# DaysSinceLastTradingSession        0.1        0.4         7.2         9.8
# Range 30MA                         2.2        3.3         3.6         5.3
# Range 7MA                          3.3        5.0         3.0         2.3
# #Trades 60MA                       3.0        3.6         5.2         1.9
# VWAP 60MA                          4.5        2.6         3.9         2.2
# Close 15MA                         6.6        2.8         2.5         1.1
# Volume 60MA                        4.1        5.1         2.3         1.2
# 52W L                              0.5        2.5         4.2         5.3
# Range 15MA                         2.5        2.7         2.8         4.4
# VWAP 7MA                           5.1        3.2         2.2         1.2
# VWAP 30MA                          5.2        2.4         2.6         0.9
# Close 60MA                         4.5        2.5         2.7         1.5
# Close 30MA                         4.3        2.6         2.6         1.1
# Low                                4.7        4.2         0.7         0.6
# VWAP 15MA                          3.7        2.1         2.9         1.4
# Open                               5.1        3.6         0.9         0.1
# Year                               0.7        0.9         1.3         5.7
# Quarter                            0.4        0.8         2.1         5.0
# Close 7MA                          3.9        1.6         1.6         0.5
# Value 60MA                         1.6        3.2         1.5         0.8
# VWAP                               3.3        2.3         1.0         0.4
# Day                                1.7        2.1         1.9         0.6
# LTP                                3.3        2.0         0.5         0.6
# #Trades 30MA                       0.8        1.2         3.6         0.6
# High                               2.9        1.7         1.2         0.4
# Volume 30MA                        1.7        1.6         1.7         0.2
# Value 7MA                          1.1        1.8         0.5         0.4
# Value 30MA                         0.8        1.3         1.1         0.4
# #Trades 7MA                        0.6        1.3         0.9         0.5
# #Trades 15MA                       0.7        1.4         0.7         0.4
# Volume 15MA                        0.3        1.1         0.7         0.7
# Value 15MA                         0.2        0.9         1.2         0.3
# Volume 7MA                         0.4        0.7         0.9         0.2
# Weekday                            0.1        0.5         0.1         0.1
# Is52WLow                           0.1        0.5         0.1         0.0
# IsGreen                            0.1        0.0         0.0         0.1
# Is52WHigh                          0.0        0.0         0.0         0.0
#
#                              Mean
# 52W H                         8.2
# Range 60MA                    7.4
# DayOfYear                     7.0
# Month                         5.0
# DaysSinceLastTradingSession   4.4
# Range 30MA                    3.6
# Range 7MA                     3.4
# #Trades 60MA                  3.4
# VWAP 60MA                     3.3
# Close 15MA                    3.2
# Volume 60MA                   3.2
# 52W L                         3.1
# Range 15MA                    3.1
# VWAP 7MA                      2.9
# VWAP 30MA                     2.8
# Close 60MA                    2.8
# Close 30MA                    2.7
# Low                           2.6
# VWAP 15MA                     2.5
# Open                          2.4
# Year                          2.1
# Quarter                       2.1
# Close 7MA                     1.9
# Value 60MA                    1.8
# VWAP                          1.8
# Day                           1.6
# LTP                           1.6
# #Trades 30MA                  1.6
# High                          1.5
# Volume 30MA                   1.3
# Value 7MA                     1.0
# Value 30MA                    0.9
# #Trades 7MA                   0.8
# #Trades 15MA                  0.8
# Volume 15MA                   0.7
# Value 15MA                    0.7
# Volume 7MA                    0.5
# Weekday                       0.2
# Is52WLow                      0.2
# IsGreen                       0.0
# Is52WHigh                     0.0

# %% [markdown]
# ## Forecasts

# %%
stock_df.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-10:, :]
# Out:
#            Date    Close  Pred Target 3D  Pred Target 7D  Pred Target 15D  \
# 1015 2024-01-09  1650.50         1644.65         1635.05          1634.33
# 1016 2024-01-10  1655.95         1648.96         1634.63          1640.57
# 1017 2024-01-11  1649.00         1643.94         1629.75          1633.27
# 1018 2024-01-12  1641.20         1635.47         1623.65          1627.85
# 1019 2024-01-15  1672.80         1660.21         1661.33          1658.70
# 1020 2024-01-16  1679.15         1668.12         1667.41          1663.33
# 1021 2024-01-17  1537.50         1519.49         1474.23          1486.26
# 1022 2024-01-18  1486.15         1451.94         1406.97          1433.03
# 1023 2024-01-19  1470.65         1440.31         1431.58          1406.34
# 1024 2024-01-20  1478.85         1484.74         1493.51          1478.80
#
#       Pred Target 30D
# 1015          1613.72
# 1016          1625.40
# 1017          1616.87
# 1018          1600.76
# 1019          1644.00
# 1020          1648.26
# 1021          1492.15
# 1022          1460.29
# 1023          1449.48
# 1024          1479.15

# %%
latest_preds = stock_df.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-1]
print(f"Date: {latest_preds['Date'].date()}")
print(f"Close: {latest_preds['Close']}")

for pred in expected_errors.keys():
    print(f"{pred}: {latest_preds[pred]} ± {expected_errors[pred] * latest_preds['Close']:.2f}")
# Out:
# Date: 2024-01-20
# Close: 1478.85
# Pred Target 3D: 1484.74 ± 41.00
# Pred Target 7D: 1493.51 ± 58.03
# Pred Target 15D: 1478.8 ± 73.85
# Pred Target 30D: 1479.15 ± 84.60
