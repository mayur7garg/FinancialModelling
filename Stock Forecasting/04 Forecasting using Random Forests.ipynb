# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import constants as cnst
import stock_utils as su

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = su.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['HDFCBANK', 'ITBEES']

# %%
STOCK_SYMBOL = stock_symbols[0]
STOCK_SYMBOL
# Out:
# 'HDFCBANK'

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Stock data

# %%
stock_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-processed.parquet')
)

stock_df
# Out:
#            Date     Open     High      Low      LTP    Close     VWAP   52W H  \
# 0    2020-01-01  1276.10  1280.00  1270.60  1279.00  1278.60  1276.64  2503.3
# 1    2020-01-02  1279.00  1288.00  1279.00  1286.00  1286.75  1284.56  2503.3
# 2    2020-01-03  1282.20  1285.00  1263.60  1268.50  1268.40  1270.48  2503.3
# 3    2020-01-06  1260.00  1261.80  1236.00  1240.25  1240.95  1247.24  2503.3
# 4    2020-01-07  1258.90  1271.45  1252.25  1261.00  1260.60  1261.48  2503.3
# ...         ...      ...      ...      ...      ...      ...      ...     ...
# 1020 2024-01-16  1673.00  1683.65  1658.10  1678.00  1679.15  1672.44  1757.5
# 1021 2024-01-17  1570.00  1596.80  1528.40  1542.15  1537.50  1565.65  1757.5
# 1022 2024-01-18  1494.00  1515.00  1480.05  1490.00  1486.15  1495.03  1757.5
# 1023 2024-01-19  1505.95  1510.25  1468.40  1474.90  1470.65  1483.88  1757.5
# 1024 2024-01-20  1483.20  1495.70  1476.00  1480.65  1478.85  1483.92  1757.5
#
#         52W L    Volume         Value  #Trades  IsGreen  Is52WLow  Is52WHigh  \
# 0     1084.00   1836849  2.345001e+09    46625        1         0          0
# 1     1084.00   3068583  3.941792e+09   104570        1         0          0
# 2     1084.00   5427775  6.895886e+09   157066        0         0          0
# 3     1084.00   5445093  6.791348e+09   155007        0         0          0
# 4     1084.00   7362247  9.287302e+09   189026        1         0          0
# ...       ...       ...           ...      ...      ...       ...        ...
# 1020  1460.25  12661250  2.117514e+10   347404        1         0          0
# 1021  1460.25  85072618  1.331936e+11  2098772        0         0          0
# 1022  1460.25  80535465  1.204027e+11  1582497        0         0          0
# 1023  1460.25  54800269  8.131686e+10  1275220        0         0          0
# 1024  1460.25  12920293  1.917264e+10   403196        0         0          0
#
#       Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0       1      1  2020        2          1        1
# 1       2      1  2020        3          2        1
# 2       3      1  2020        4          3        1
# 3       6      1  2020        0          6        1
# 4       7      1  2020        1          7        1
# ...   ...    ...   ...      ...        ...      ...
# 1020   16      1  2024        1         16        1
# 1021   17      1  2024        2         17        1
# 4           130458    1282.70    1287.65     1223.20     1217.15
# ...            ...        ...        ...         ...         ...
# 1020        336519    1470.65        NaN         NaN         NaN
# 1021        393241    1478.85        NaN         NaN         NaN
# 1022        434624        NaN        NaN         NaN         NaN
# 1023        469801        NaN        NaN         NaN         NaN
# 1024        470835        NaN        NaN         NaN         NaN
#
# [1025 rows x 46 columns]

# %% [markdown]
# ### Standardized data

# %%
standardized_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-standardized.parquet')
)

standardized_df
# Out:
#        Open   High    Low    LTP   VWAP  52W H  52W L  IsGreen  Is52WLow  \
# 0     0.998  1.001  0.994  1.000  0.998  1.958  0.848        1         0
# 1     0.994  1.001  0.994  0.999  0.998  1.945  0.842        1         0
# 2     1.011  1.013  0.996  1.000  1.002  1.974  0.855        0         0
# 3     1.015  1.017  0.996  0.999  1.005  2.017  0.874        0         0
# 4     0.999  1.009  0.993  1.000  1.001  1.986  0.860        1         0
# ...     ...    ...    ...    ...    ...    ...    ...      ...       ...
# 1020  0.996  1.003  0.987  0.999  0.996  1.047  0.870        1         0
# 1021  1.021  1.039  0.994  1.003  1.018  1.143  0.950        0         0
# 1022  1.005  1.019  0.996  1.003  1.006  1.183  0.983        0         0
# 1023  1.024  1.027  0.998  1.003  1.009  1.195  0.993        0         0
# 1024  1.003  1.011  0.998  1.001  1.003  1.188  0.987        0         0
#
#       Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0             0    1      1  2020        2          1        1
# 1             0    2      1  2020        3          2        1
# 2             0    3      1  2020        4          3        1
# 3             0    6      1  2020        0          6        1
# 4             0    7      1  2020        1          7        1
# ...         ...  ...    ...   ...      ...        ...      ...
# 1020          0   16      1  2024        1         16        1
# 1021          0   17      1  2024        2         17        1
# 1022          0   18      1  2024        3         18        1
# 1023          0   19      1  2024        4         19        1
# 1024          0   20      1  2024        5         20        1
#
#       DaysSinceLastTradingSession  Close 3MA  Close 7MA  Close 15MA  \
# 0                               1      1.000      1.000       1.000
# 1                               1      0.997      0.997       0.997
# 2                               1      1.008      1.008       1.008
# 3                               3      1.020      1.022       1.022
# 4                               1      0.997      1.005       1.005
# ...                           ...        ...        ...         ...
# 1020                            1      0.991      0.988       0.999
# 1021                            1      1.060      1.067       1.084
# 1022                            1      1.055      1.088       1.112
# 1023                            1      1.019      1.082       1.113
# 1024                            1      1.000      1.059       1.097
#
#       Close 30MA  VWAP 3MA  VWAP 7MA  VWAP 15MA  VWAP 30MA  Volume 3MA  \
# 0          1.000     0.998     0.998      0.998      0.998       1.000
# 1          0.997     0.995     0.995      0.995      0.995       0.799
# 2          1.008     1.007     1.007      1.007      1.007       0.635
# 3          1.022     1.021     1.023      1.023      1.023       0.853
# 4          1.005     0.999     1.006      1.006      1.006       0.826
# ...          ...       ...       ...        ...        ...         ...
# 1020       0.991     0.989     0.989      1.000      0.991       0.966
# 1021       1.081     1.063     1.070      1.086      1.081       0.438
# 1022       1.115     1.062     1.091      1.114      1.116       0.738
# 1023       1.123     1.030     1.086      1.116      1.124       1.341
# 1024       1.113     1.006     1.064      1.100      1.114       3.825
#
#       Volume 7MA  Volume 15MA  Volume 30MA  Value 3MA  Value 7MA  Value 15MA  \
# 0          1.000        1.000        1.000      1.000      1.000       1.000
# 1          0.799        0.799        0.799      0.797      0.797       0.797
# 2          0.635        0.635        0.635      0.637      0.637       0.637
# 3          0.724        0.724        0.724      0.865      0.735       0.735
# 4          0.629        0.629        0.629      0.825      0.630       0.630
# ...          ...          ...          ...        ...        ...         ...
# 1020       0.853        0.995        1.271      0.961      0.847       1.000
# 1021       0.255        0.204        0.212      0.445      0.261       0.214
# 1022       0.389        0.264        0.250      0.761      0.407       0.283
# 1023       0.694        0.439        0.394      1.373      0.722       0.468
# 1024       2.986        1.894        1.660      3.840      3.093       2.008
#
#       Value 30MA  #Trades 3MA  #Trades 7MA  #Trades 15MA  #Trades 30MA  \
# 0          1.000        1.000        1.000         1.000         1.000
# 1          0.797        0.723        0.723         0.723         0.723
# 2          0.637        0.654        0.654         0.654         0.654
# 3          0.735        0.896        0.747         0.747         0.747
# 4          0.630        0.884        0.690         0.690         0.690
# ...          ...          ...          ...           ...           ...
# 1020       1.264        0.999        0.857         0.935         0.969
# 1021       0.224        0.454        0.260         0.211         0.187
# 1022       0.272        0.849        0.463         0.329         0.275
# 1023       0.429        1.296        0.698         0.461         0.368
# 1024       1.805        2.696        2.268         1.482         1.168
#
#       Target 3D  Target 7D  Target 15D  Target 30D
# 0         0.971      1.003       0.970       0.970
# 1         0.980      0.999       0.967       0.971
# 2         0.991      1.017       0.981       0.979
# 3         1.025      1.035       0.978       0.983
# 4         1.018      1.021       0.970       0.966
# ...         ...        ...         ...         ...
# 1020      0.876        NaN         NaN         NaN
# 1021      0.962        NaN         NaN         NaN
# 1022        NaN        NaN         NaN         NaN
# 1023        NaN        NaN         NaN         NaN
# 1024        NaN        NaN         NaN         NaN
#
# [1025 rows x 41 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = standardized_df.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
standardized_df[target_cols].describe()
# Out:
#          Target 3D    Target 7D   Target 15D  Target 30D
# count  1022.000000  1018.000000  1010.000000  995.000000
# mean      1.000904     1.002511     1.005721    1.012089
# std       0.031153     0.046105     0.064164    0.086329
# min       0.820000     0.718000     0.668000    0.629000
# 25%       0.985000     0.978000     0.968000    0.963000
# 50%       1.000000     1.002000     1.003000    1.009000
# 75%       1.016750     1.026000     1.043000    1.060000
# max       1.178000     1.219000     1.231000    1.322000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = standardized_df[standardized_df[target_col].notnull()].drop(columns = target_cols).copy()
    y = standardized_df[standardized_df[target_col].notnull()][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = standardized_df.drop(columns = target_cols).columns.to_list()
)

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 10,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(model, X, y):
    preds = model.predict(X)
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {mean_squared_error(y, preds, squared = False):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (1022, 37)
# y.shape: (1022,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 1.0,
#  'max_features': 'sqrt',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.256220      0.010191         0.048205        0.007833
# 9       0.262103      0.006494         0.038111        0.004792
# 3       0.196570      0.007393         0.033852        0.007945
# 0       0.344619      0.062861         0.044164        0.003954
# 4       0.198915      0.004395         0.030555        0.001456
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 8                100               1.0               sqrt               4
# 9                100              0.75               log2               4
# 3                 75               1.0               0.25               4
# 0                100               1.0               log2               5
# 4                 75              0.75               log2               5
#
#                                               params  split0_test_score  \
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.050120
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.049237
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.059623
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.059853
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.065547
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8          -0.018000          -0.042307           0.001650           0.003465
# 9          -0.022100          -0.042504           0.009265          -0.002040
# 3          -0.013150          -0.047051          -0.001813           0.004731
# 0          -0.016675          -0.052321           0.007496           0.004037
# 4          -0.023169          -0.060264           0.003571           0.004484
#
#    mean_test_score  std_test_score  rank_test_score
# 8        -0.021062        0.022011                1
# 9        -0.021323        0.022521                2
# 3        -0.023381        0.025432                3
# 0        -0.023463        0.027992                4
# 4        -0.028185        0.030086                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

print_results(model, X, y)
# Out:
# Target std: 0.031
# R2: 0.211
# MSE: 0.028
# MAE: 0.020

# %%
stock_df[f'Pred {target_col}'] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, f'Pred {target_col}']].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 3D  Pred Target 3D
# 1012 2024-01-04  1690.85    1650.50         1686.14
# 1013 2024-01-05  1682.20    1655.95         1677.52
# 1014 2024-01-08  1663.45    1649.00         1658.49
# 1015 2024-01-09  1650.50    1641.20         1646.62
# 1016 2024-01-10  1655.95    1672.80         1651.56
# 1017 2024-01-11  1649.00    1679.15         1645.43
# 1018 2024-01-12  1641.20    1537.50         1632.89
# 1019 2024-01-15  1672.80    1486.15         1659.23
# 1020 2024-01-16  1679.15    1470.65         1666.71
# 1021 2024-01-17  1537.50    1478.85         1518.87

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (1018, 37)
# y.shape: (1018,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.288481      0.004990         0.042047        0.001090
# 9       0.291293      0.006469         0.041886        0.000525
# 4       0.261719      0.018350         0.036050        0.004762
# 3       0.231258      0.021300         0.031467        0.001287
# 6       0.418033      0.019289         0.049393        0.006242
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 8                100               1.0               sqrt               4
# 9                100              0.75               log2               4
# 4                 75              0.75               log2               5
# 3                 75               1.0               0.25               4
# 6                125              0.75               0.25               5
#
#                                               params  split0_test_score  \
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.077273
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.065703
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.094345
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.125756
# 6  {'n_estimators': 125, 'max_samples': 0.75, 'ma...          -0.091230
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8          -0.049769          -0.116930           0.034086          -0.029044
# 9          -0.059577          -0.135089           0.026353          -0.021251
# 4          -0.069594          -0.117838           0.018466          -0.029128
# 3          -0.059310          -0.108515           0.036431          -0.037832
# 6          -0.078813          -0.182782           0.040820          -0.013041
#
#    mean_test_score  std_test_score  rank_test_score
# 8        -0.047786        0.050416                1
# 9        -0.051054        0.053347                2
# 4        -0.058488        0.048405                3
# 3        -0.058996        0.057382                4
# 6        -0.065009        0.075695                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

print_results(model, X, y)
# Out:
# Target std: 0.046
# R2: 0.268
# MSE: 0.039
# MAE: 0.029

# %%
stock_df[f'Pred {target_col}'] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, f'Pred {target_col}']].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 7D  Pred Target 7D
# 1008 2023-12-29  1709.25    1650.50         1717.00
# 1009 2024-01-01  1698.10    1655.95         1678.90
# 1010 2024-01-02  1699.10    1649.00         1684.87
# 1011 2024-01-03  1672.90    1641.20         1657.83
# 1012 2024-01-04  1690.85    1672.80         1677.78
# 1013 2024-01-05  1682.20    1679.15         1669.49
# 1014 2024-01-08  1663.45    1537.50         1640.09
# 1015 2024-01-09  1650.50    1486.15         1630.19
# 1016 2024-01-10  1655.95    1470.65         1628.88
# 1017 2024-01-11  1649.00    1478.85         1626.63

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (1010, 37)
# y.shape: (1010,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.394142      0.020790         0.051346        0.004224
# 0       0.385838      0.049346         0.043355        0.002433
# 4       0.237175      0.005821         0.031357        0.002073
# 8       0.308641      0.017508         0.044625        0.006940
# 3       0.225014      0.003692         0.032860        0.004263
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 0                100               1.0               log2               5
# 4                 75              0.75               log2               5
# 8                100               1.0               sqrt               4
# 3                 75               1.0               0.25               4
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.144242
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.204038
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.251312
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.216418
# 3  {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.357147
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.082260          -0.177313           0.058198          -0.248818
# 0          -0.101458          -0.221351           0.102964          -0.243059
# 4          -0.079728          -0.209183           0.111611          -0.243851
# 8          -0.069708          -0.211173           0.066251          -0.262384
# 3          -0.081209          -0.160509           0.121428          -0.273947
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.118887        0.103575                1
# 0        -0.133388        0.127780                2
# 4        -0.134493        0.137660                3
# 8        -0.138686        0.121124                4
# 3        -0.150277        0.165401                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

print_results(model, X, y)
# Out:
# Target std: 0.064
# R2: 0.352
# MSE: 0.052
# MAE: 0.040

# %%
stock_df[f'Pred {target_col}'] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, f'Pred {target_col}']].dropna().iloc[-10:, :]
# Out:
#            Date    Close  Target 15D  Pred Target 15D
# 1000 2023-12-18  1655.70     1650.50          1668.93
# 1001 2023-12-19  1652.90     1655.95          1663.68
# 1002 2023-12-20  1657.00     1649.00          1669.59
# 1003 2023-12-21  1686.70     1641.20          1699.44
# 1004 2023-12-22  1670.85     1672.80          1684.63
# 1005 2023-12-26  1682.45     1679.15          1694.66
# 1006 2023-12-27  1703.30     1537.50          1714.35
# 1007 2023-12-28  1705.25     1486.15          1717.83
# 1008 2023-12-29  1709.25     1470.65          1719.39
# 1009 2024-01-01  1698.10     1478.85          1673.97

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (995, 37)
# y.shape: (995,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 0.75,
#  'max_features': 'log2',
#  'max_depth': 4}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9       0.299857      0.014563         0.043453        0.002165
# 0       0.480171      0.068390         0.057630        0.012795
# 8       0.299128      0.008916         0.042920        0.001708
# 4       0.254781      0.008177         0.034523        0.004786
# 5       0.441536      0.022503         0.051975        0.003184
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 9                100              0.75               log2               4
# 0                100               1.0               log2               5
# 8                100               1.0               sqrt               4
# 4                 75              0.75               log2               5
# 5                125               1.0               sqrt               5
#
#                                               params  split0_test_score  \
# 9  {'n_estimators': 100, 'max_samples': 0.75, 'ma...          -0.464071
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.595103
# 8  {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.790413
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.674931
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.777962
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 9          -0.028794          -0.436321           0.098886          -0.384824
# 0          -0.009222          -0.580303           0.135407          -0.295183
# 8          -0.014551          -0.437596           0.145117          -0.304796
# 4          -0.005484          -0.551650           0.100873          -0.305285
# 5           0.023647          -0.701150           0.147535          -0.239720
#
#    mean_test_score  std_test_score  rank_test_score
# 9        -0.243025        0.232004                1
# 0        -0.268881        0.294947                2
# 8        -0.280448        0.327768                3
# 4        -0.287295        0.300187                4
# 5        -0.309530        0.373519                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

print_results(model, X, y)
# Out:
# Target std: 0.086
# R2: 0.472
# MSE: 0.063
# MAE: 0.049

# %%
stock_df[f'Pred {target_col}'] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, f'Pred {target_col}']].dropna().iloc[-10:, :]
# Out:
#           Date    Close  Target 30D  Pred Target 30D
# 985 2023-11-24  1532.10     1650.50          1564.23
# 986 2023-11-28  1528.65     1655.95          1565.61
# 987 2023-11-29  1559.15     1649.00          1591.69
# 988 2023-11-30  1558.80     1641.20          1584.54
# 989 2023-12-01  1555.40     1672.80          1585.05
# 990 2023-12-04  1609.40     1679.15          1634.39
# 991 2023-12-05  1623.70     1537.50          1647.08
# 992 2023-12-06  1627.80     1486.15          1651.08
# 993 2023-12-07  1630.45     1470.65          1656.77
# 994 2023-12-08  1653.20     1478.85          1678.45

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# 52W H                             17.3       20.2        12.6        12.5
# DayOfYear                          2.7        8.0         9.6        13.3
# VWAP 15MA                          9.1        4.3         5.0         4.4
# DaysSinceLastTradingSession        0.0        0.7        10.2         8.6
# Month                              0.6        3.4         4.4         9.5
# Close 15MA                         8.0        4.3         2.5         2.0
# VWAP 30MA                          6.7        4.0         2.5         1.5
# VWAP 7MA                           6.2        2.8         2.7         3.0
# 52W L                              1.0        3.0         4.2         6.2
# Quarter                            0.5        1.0         3.5         9.0
# Low                                7.0        4.7         1.2         0.9
# Open                               5.8        5.5         1.7         0.7
# VWAP                               5.4        4.0         1.9         1.1
# Close 30MA                         4.6        2.7         3.8         1.3
# Year                               1.3        1.3         3.3         5.9
# #Trades 30MA                       0.6        2.2         6.6         2.1
# Close 7MA                          3.6        3.0         1.7         2.1
# High                               2.5        1.7         2.2         1.7
# Volume 30MA                        1.6        2.4         2.4         1.3
# Day                                1.3        3.7         1.6         0.7
# LTP                                2.7        1.3         1.2         1.5
# #Trades 15MA                       0.9        1.2         2.7         1.6
# VWAP 3MA                           1.2        2.2         1.7         0.9
# Close 3MA                          2.5        1.4         1.0         0.9
# Value 30MA                         0.6        1.9         1.1         1.7
# Value 3MA                          1.4        1.6         1.1         0.5
# #Trades 7MA                        0.5        1.2         1.5         1.0
# Volume 7MA                         0.9        0.9         1.4         0.8
# Volume 3MA                         0.7        1.5         0.9         0.5
# Volume 15MA                        0.6        0.9         1.2         0.8
# Value 7MA                          0.5        1.0         0.8         0.9
# Value 15MA                         0.7        0.8         1.0         0.5
# #Trades 3MA                        0.5        0.5         0.4         0.4
# Weekday                            0.6        0.3         0.1         0.1
# Is52WLow                           0.0        0.4         0.1         0.1
# Is52WHigh                          0.0        0.0         0.0         0.1
# IsGreen                            0.0        0.0         0.0         0.0
#
#                              Mean
# 52W H                        15.6
# DayOfYear                     8.4
# VWAP 15MA                     5.7
# DaysSinceLastTradingSession   4.9
# Month                         4.5
# Close 15MA                    4.2
# VWAP 30MA                     3.7
# VWAP 7MA                      3.7
# 52W L                         3.6
# Quarter                       3.5
# Low                           3.4
# Open                          3.4
# VWAP                          3.1
# Close 30MA                    3.1
# Year                          2.9
# #Trades 30MA                  2.9
# Close 7MA                     2.6
# High                          2.0
# Volume 30MA                   1.9
# Day                           1.8
# LTP                           1.7
# #Trades 15MA                  1.6
# VWAP 3MA                      1.5
# Close 3MA                     1.5
# Value 30MA                    1.3
