# %% [markdown]
# # 04 - Forecasting using Random Forests

# %%
import sys
sys.executable
# Out:
# '/usr/local/bin/python'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import constants as cnst
import stock_utils as su

pd.set_option('display.max_columns', None)
# Out:
# NSE_DATA_DIR = PosixPath('../data/NSE') | Valid: True
# PROCESSED_DATA_DIR = PosixPath('../data/processed') | Valid: True

# %% [markdown]
# ## Constants

# %%
stock_symbols = su.get_all_stock_symbols(
    cnst.NSE_DATA_DIR
)

stock_symbols
# Out:
# ['DEEPAKFERT', 'HDFCBANK', 'ITBEES', 'JUBLFOOD']

# %%
STOCK_SYMBOL = stock_symbols[0]
STOCK_SYMBOL
# Out:
# 'DEEPAKFERT'

# %% [markdown]
# ## Data loading

# %% [markdown]
# ### Stock data

# %%
stock_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-processed.parquet')
)

stock_df
# Out:
#           Date    Open    High     Low     LTP   Close    VWAP  52W H   52W L  \
# 0   2020-01-01   97.20   97.85   96.30   96.60   96.75   96.95  169.0   76.20
# 1   2020-01-02   96.85  102.40   96.60  100.00  100.35  100.17  169.0   76.20
# 2   2020-01-03   99.70  104.80   99.00  101.20  100.75  101.90  169.0   76.20
# 3   2020-01-06  100.50  100.85   95.25   95.70   96.10   97.91  169.0   76.20
# 4   2020-01-07   97.35  101.00   97.10   99.95  100.40   99.09  169.0   76.20
# ..         ...     ...     ...     ...     ...     ...     ...    ...     ...
# 976 2024-02-12  515.50  517.10  497.85  502.80  500.05  506.51  714.7  497.85
# 977 2024-02-13  500.10  503.80  483.35  498.95  495.05  493.89  714.7  483.35
# 978 2024-02-14  495.00  499.70  488.50  490.25  490.80  493.16  714.7  483.35
# 979 2024-02-15  493.50  515.30  491.95  508.10  507.90  508.02  714.7  483.35
# 980 2024-02-16  506.50  514.40  492.70  494.65  494.50  500.85  714.7  483.35
#
#      Volume         Value  #Trades  Range  IsGreen  Is52WLow  Is52WHigh  Day  \
# 0    153261  1.485918e+07     3161   1.55        0         0          0    1
# 1    637039  6.381519e+07     7526   5.80        1         0          0    2
# 2    562843  5.735485e+07     7402   5.80        1         0          0    3
# 3    326011  3.192018e+07     5214   5.60        0         0          0    6
# 4    307107  3.043237e+07     4983   3.90        1         0          0    7
# ..      ...           ...      ...    ...      ...       ...        ...  ...
# 976  654659  3.315936e+08    26328  19.25        0         1          0   12
# 977  827799  4.088438e+08    39023  20.45        0         1          0   13
# 978  633883  3.126049e+08    31700  11.20        0         0          0   14
# 979  995334  5.056480e+08    49286  23.35        1         0          0   15
# 980  777790  3.895585e+08    29460  21.70        0         0          0   16
#
#      Month  Year  Weekday  DayOfYear  Quarter  DaysSinceLastTradingSession  \
# 0        1  2020        2          1        1                            1
# 1        1  2020        3          2        1                            1
# 2        1  2020        4          3        1                            1
# 3        1  2020        0          6        1                            3
# 4        1  2020        1          7        1                            1
# ..     ...   ...      ...        ...      ...                          ...
# 976      2  2024        0         43        1                            3
# 977      2  2024        1         44        1                            1
# 978      2  2024        2         45        1                            1
# 979      2  2024        3         46        1                            1
# 980      2  2024        4         47        1                            1
#
#      Close 7MA  Close 15MA  Close 30MA  Close 60MA  Range 7MA  Range 15MA  \
# 0        96.75       96.75       96.75       96.75       1.55        1.55
# 1        98.55       98.55       98.55       98.55       3.68        3.68
# 2        99.28       99.28       99.28       99.28       4.38        4.38
# 3        98.49       98.49       98.49       98.49       4.69        4.69
# 4        98.87       98.87       98.87       98.87       4.53        4.53
# ..         ...         ...         ...         ...        ...         ...
# 976     532.51      581.46      623.67      634.67      22.49       23.74
# 977     521.22      571.23      617.25      632.67      21.92       23.85
# 978     514.09      562.03      610.53      630.67      17.86       22.40
# 979     509.79      553.37      604.57      629.15      18.63       22.59
# 980     503.99      543.85      597.86      627.38      19.37       22.62
#
#      Range 30MA  Range 60MA  VWAP 7MA  VWAP 15MA  VWAP 30MA  VWAP 60MA  \
# 0          1.55        1.55     96.95      96.95      96.95      96.95
# 1          3.68        3.68     98.56      98.56      98.56      98.56
# 2          4.38        4.38     99.67      99.67      99.67      99.67
# 3          4.69        4.69     99.23      99.23      99.23      99.23
# 4          4.53        4.53     99.20      99.20      99.20      99.20
# ..          ...         ...       ...        ...        ...        ...
# 976       21.57       21.98    538.22     586.38     627.50     637.57
# 977       21.44       22.16    525.74     575.63     620.93     635.50
# 978       21.00       22.15    517.33     566.06     614.19     633.49
# 979       21.34       22.26    512.59     557.76     608.17     631.92
# 980       21.50       22.43    507.01     548.50     601.57     630.29
#
#      Volume 7MA  Volume 15MA  Volume 30MA  Volume 60MA  Value 7MA  Value 15MA  \
# 0        153261       153261       153261       153261   14859179    14859179
# 1        395150       395150       395150       395150   39337186    39337186
# 2        451047       451047       451047       451047   45343075    45343075
# 3        419788       419788       419788       419788   41987352    41987352
# 4        397252       397252       397252       397252   39676356    39676356
# ..          ...          ...          ...          ...        ...         ...
# 976      928983       781001       679848       729576  506187770   450855191
# 977      858821       808121       657226       739972  455081470   459721553
# 978      735754       818019       640038       747111  381813171   459958157
# 979      711399       860316       656385       757426  363912813   478450515
# 980      732773       873543       659817       764517  371113144   479709232
#
#      Value 30MA  Value 60MA  #Trades 7MA  #Trades 15MA  #Trades 30MA  \
# 0      14859179    14859179         3161          3161          3161
# 1      39337186    39337186         5343          5343          5343
# 2      45343075    45343075         6029          6029          6029
# 3      41987352    41987352         5825          5825          5825
# 4      39676356    39676356         5657          5657          5657
# ..          ...         ...          ...           ...           ...
# 976   420705230   467952521        35476         29835         24604
# 977   399636888   472665722        34396         31390         24655
# 978   383406355   475772685        30659         31969         24742
# 979   388672600   480421170        32106         34057         25877
# 980   385938137   483398252        32496         34506         26215
#
#      #Trades 60MA  Target 3D  Target 7D  Target 15D  Target 30D
# 0            3161      96.10     106.20      109.70      107.00
# 1            5343     100.40     109.65      111.55      103.30
# 2            6029      98.95     115.30      114.85       99.45
# 3            5825     106.30     119.85      121.25       99.95
# 4            5657     106.20     118.20      116.60       96.55
# ..            ...        ...        ...         ...         ...
# 976         24325     507.90        NaN         NaN         NaN
# 977         24855     494.50        NaN         NaN         NaN
# 978         25240        NaN        NaN         NaN         NaN
# 979         25807        NaN        NaN         NaN         NaN
# 980         26094        NaN        NaN         NaN         NaN
#
# [981 rows x 51 columns]

# %% [markdown]
# ### Standardized data

# %%
standardized_df = pd.read_parquet(
    cnst.PROCESSED_DATA_DIR.joinpath(f'{STOCK_SYMBOL}-standardized.parquet')
)

standardized_df
# Out:
#       Open   High    Low    LTP   VWAP  52W H  52W L  IsGreen  Is52WLow  \
# 0    1.005  1.011  0.995  0.998  1.002  1.747  0.788        0         0
# 1    0.965  1.020  0.963  0.997  0.998  1.684  0.759        1         0
# 2    0.990  1.040  0.983  1.004  1.011  1.677  0.756        1         0
# 3    1.046  1.049  0.991  0.996  1.019  1.759  0.793        0         0
# 4    0.970  1.006  0.967  0.996  0.987  1.683  0.759        1         0
# ..     ...    ...    ...    ...    ...    ...    ...      ...       ...
# 976  1.031  1.034  0.996  1.005  1.013  1.429  0.996        0         1
# 977  1.010  1.018  0.976  1.008  0.998  1.444  0.976        0         1
# 978  1.009  1.018  0.995  0.999  1.005  1.456  0.985        0         0
# 979  0.972  1.015  0.969  1.000  1.000  1.407  0.952        1         0
# 980  1.024  1.040  0.996  1.000  1.013  1.445  0.977        0         0
#
#      Is52WHigh  Day  Month  Year  Weekday  DayOfYear  Quarter  \
# 0            0    1      1  2020        2          1        1
# 1            0    2      1  2020        3          2        1
# 2            0    3      1  2020        4          3        1
# 3            0    6      1  2020        0          6        1
# 4            0    7      1  2020        1          7        1
# ..         ...  ...    ...   ...      ...        ...      ...
# 976          0   12      2  2024        0         43        1
# 977          0   13      2  2024        1         44        1
# 978          0   14      2  2024        2         45        1
# 979          0   15      2  2024        3         46        1
# 980          0   16      2  2024        4         47        1
#
#      DaysSinceLastTradingSession  Close 7MA  Close 15MA  Close 30MA  \
# 0                              1      1.000       1.000       1.000
# 1                              1      0.982       0.982       0.982
# 2                              1      0.985       0.985       0.985
# 3                              3      1.025       1.025       1.025
# 4                              1      0.985       0.985       0.985
# ..                           ...        ...         ...         ...
# 976                            3      1.065       1.163       1.247
# 977                            1      1.053       1.154       1.247
# 978                            1      1.047       1.145       1.244
# 979                            1      1.004       1.090       1.190
# 980                            1      1.019       1.100       1.209
#
#      Close 60MA  Range 7MA  Range 15MA  Range 30MA  Range 60MA  VWAP 7MA  \
# 0         1.000      0.016       0.016       0.016       0.016     1.002
# 1         0.982      0.037       0.037       0.037       0.037     0.982
# 2         0.985      0.043       0.043       0.043       0.043     0.989
# 3         1.025      0.049       0.049       0.049       0.049     1.033
# 4         0.985      0.045       0.045       0.045       0.045     0.988
# ..          ...        ...         ...         ...         ...       ...
# 976       1.269      0.045       0.047       0.043       0.044     1.076
# 977       1.278      0.044       0.048       0.043       0.045     1.062
# 978       1.285      0.036       0.046       0.043       0.045     1.054
# 979       1.239      0.037       0.044       0.042       0.044     1.009
# 980       1.269      0.039       0.046       0.043       0.045     1.025
#
#      VWAP 15MA  VWAP 30MA  VWAP 60MA  Volume 7MA  Volume 15MA  Volume 30MA  \
# 0        1.002      1.002      1.002       1.000        1.000        1.000
# 1        0.982      0.982      0.982       0.620        0.620        0.620
# 2        0.989      0.989      0.989       0.801        0.801        0.801
# 3        1.033      1.033      1.033       1.288        1.288        1.288
# 4        0.988      0.988      0.988       1.294        1.294        1.294
# ..         ...        ...        ...         ...          ...          ...
# 976      1.173      1.255      1.275       1.419        1.193        1.038
# 977      1.163      1.254      1.284       1.037        0.976        0.794
# 978      1.153      1.251      1.291       1.161        1.290        1.010
# 979      1.098      1.197      1.244       0.715        0.864        0.659
# 980      1.109      1.217      1.275       0.942        1.123        0.848
#
#      Volume 60MA  Value 7MA  Value 15MA  Value 30MA  Value 60MA  #Trades 7MA  \
# 0          1.000      1.000       1.000       1.000       1.000        1.000
# 1          0.620      0.616       0.616       0.616       0.616        0.710
# 2          0.801      0.791       0.791       0.791       0.791        0.815
# 3          1.288      1.315       1.315       1.315       1.315        1.117
# 4          1.294      1.304       1.304       1.304       1.304        1.135
# ..           ...        ...         ...         ...         ...          ...
# 976        1.114      1.527       1.360       1.269       1.411        1.347
# 977        0.894      1.113       1.124       0.977       1.156        0.881
# 978        1.179      1.221       1.471       1.226       1.522        0.967
# 979        0.761      0.720       0.946       0.769       0.950        0.651
# 980        0.983      0.953       1.231       0.991       1.241        1.103
#
#      #Trades 15MA  #Trades 30MA  #Trades 60MA  Target 3D  Target 7D  \
# 0           1.000         1.000         1.000      0.993      1.098
# 1           0.710         0.710         0.710      1.000      1.093
# 2           0.815         0.815         0.815      0.982      1.144
# 3           1.117         1.117         1.117      1.106      1.247
# 4           1.135         1.135         1.135      1.058      1.177
# ..            ...           ...           ...        ...        ...
# 976         1.133         0.935         0.924      1.016        NaN
# 977         0.804         0.632         0.637      0.999        NaN
# 978         1.008         0.781         0.796        NaN        NaN
# 979         0.691         0.525         0.524        NaN        NaN
# 980         1.171         0.890         0.886        NaN        NaN
#
#      Target 15D  Target 30D
# 0         1.134       1.106
# 1         1.112       1.029
# 2         1.140       0.987
# 3         1.262       1.040
# 4         1.161       0.962
# ..          ...         ...
# 976         NaN         NaN
# 977         NaN         NaN
# 978         NaN         NaN
# 979         NaN         NaN
# 980         NaN         NaN
#
# [981 rows x 45 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Target columns

# %%
target_cols = standardized_df.filter(regex = "Target.*").columns.to_list()
target_cols
# Out:
# ['Target 3D', 'Target 7D', 'Target 15D', 'Target 30D']

# %%
standardized_df[target_cols].describe()
# Out:
#         Target 3D   Target 7D  Target 15D  Target 30D
# count  978.000000  974.000000  966.000000  951.000000
# mean     1.006635    1.015753    1.034381    1.073529
# std      0.058730    0.092773    0.138773    0.201920
# min      0.803000    0.711000    0.688000    0.645000
# 25%      0.974000    0.965000    0.940250    0.931000
# 50%      1.001000    1.005500    1.016000    1.028000
# 75%      1.034000    1.057000    1.101750    1.169500
# max      1.414000    1.526000    1.562000    1.770000

# %% [markdown]
# ### Data processing

# %%
def get_training_data(target_col: str):
    print(f"Target: {target_col}")
    X_df = standardized_df[standardized_df[target_col].notnull()].drop(columns = target_cols).copy()
    y = standardized_df[standardized_df[target_col].notnull()][target_col].copy()
    print(f"X.shape: {X_df.shape}")
    print(f"y.shape: {y.shape}")

    return X_df, y

# %% [markdown]
# ### Grid search parameters

# %%
param_dict = {
    "n_estimators": [75, 100, 125],
    "max_depth": [4, 5, 6],
    "max_features": ["log2", "sqrt", 0.25],
    "max_samples": [0.75, 1.0]
}

feature_importances = pd.DataFrame(
    index = standardized_df.drop(columns = target_cols).columns.to_list()
)

expected_errors = {}

# %% [markdown]
# ### Model building

# %%
def get_model():
    rf_model = RandomForestRegressor(
        criterion = "squared_error",
        n_jobs = -1,
        random_state = cnst.RANDOM_STATE
    )

    grid_cv = RandomizedSearchCV(
        rf_model,
        param_dict,
        n_iter = 12,
        cv = 5, 
        random_state = cnst.RANDOM_STATE
    )

    return grid_cv

def print_results(y, preds):
    print(f"Target std: {y.std():.3f}")
    print(f"R2: {r2_score(y, preds):.3f}")
    print(f"MSE: {mean_squared_error(y, preds, squared = False):.3f}")
    print(f"MAE: {mean_absolute_error(y, preds):.3f}")

def expected_error(y, preds):
    return mean_squared_error(y, preds, squared = False)

# %% [markdown]
# ## Training

# %% [markdown]
# ### `Target 3D`

# %%
target_col = target_cols[0]
X, y = get_training_data(target_col)
# Out:
# Target: Target 3D
# X.shape: (978, 41)
# y.shape: (978,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 125,
#  'max_samples': 1.0,
#  'max_features': 'log2',
#  'max_depth': 6}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 10       0.527505      0.038379         0.058367        0.006812
# 2        0.378233      0.026256         0.047096        0.004470
# 8        0.336369      0.011090         0.049765        0.014759
# 7        0.274206      0.012245         0.035845        0.004916
# 1        0.353251      0.041147         0.045139        0.007589
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 10                125               1.0               log2               6
# 2                 100               1.0               0.25               5
# 8                 100               1.0               sqrt               4
# 7                  75              0.75               0.25               5
# 1                  75               1.0               sqrt               5
#
#                                                params  split0_test_score  \
# 10  {'n_estimators': 125, 'max_samples': 1.0, 'max...          -0.020781
# 2   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.017215
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...          -0.001688
# 7   {'n_estimators': 75, 'max_samples': 0.75, 'max...          -0.018586
# 1   {'n_estimators': 75, 'max_samples': 1.0, 'max_...          -0.006251
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 10          -0.039276           0.023059           0.048787
# 2           -0.043434           0.026460           0.028416
# 8           -0.039070           0.023611           0.011291
# 7           -0.048755           0.010519           0.022883
# 1           -0.046146           0.015587           0.019420
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 10          -0.069882        -0.011619        0.042649                1
# 2           -0.053626        -0.011880        0.034236                2
# 8           -0.075368        -0.016245        0.036264                3
# 7           -0.057231        -0.018234        0.031527                4
# 1           -0.075490        -0.018576        0.036775                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.059
# R2: 0.335
# MSE: 0.048
# MAE: 0.036

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#           Date   Close  Target 3D  Pred Target 3D
# 968 2024-01-31  618.15     540.75          608.66
# 969 2024-02-01  579.75     537.95          563.66
# 970 2024-02-02  574.05     535.10          563.45
# 971 2024-02-05  540.75     524.35          531.78
# 972 2024-02-06  537.95     515.30          533.50
# 973 2024-02-07  535.10     500.05          527.78
# 974 2024-02-08  524.35     495.05          518.40
# 975 2024-02-09  515.30     490.80          508.18
# 976 2024-02-12  500.05     507.90          499.43
# 977 2024-02-13  495.05     494.50          494.25

# %% [markdown]
# ### `Target 7D`

# %%
target_col = target_cols[1]
X, y = get_training_data(target_col)
# Out:
# Target: Target 7D
# X.shape: (974, 41)
# y.shape: (974,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 1.0,
#  'max_features': 'log2',
#  'max_depth': 5}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.488227      0.093889         0.057007        0.011276
# 4       0.290810      0.042490         0.041059        0.007340
# 5       0.485633      0.035842         0.054153        0.007337
# 1       0.332759      0.018132         0.041142        0.004335
# 7       0.314568      0.041354         0.042779        0.009044
#
#   param_n_estimators param_max_samples param_max_features param_max_depth  \
# 0                100               1.0               log2               5
# 4                 75              0.75               log2               5
# 5                125               1.0               sqrt               5
# 1                 75               1.0               sqrt               5
# 7                 75              0.75               0.25               5
#
#                                               params  split0_test_score  \
# 0  {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.061360
# 4  {'n_estimators': 75, 'max_samples': 0.75, 'max...           0.051066
# 5  {'n_estimators': 125, 'max_samples': 1.0, 'max...           0.054130
# 1  {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.071712
# 7  {'n_estimators': 75, 'max_samples': 0.75, 'max...           0.048981
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.110181          -0.046097           0.048762          -0.164785
# 4          -0.112585          -0.061142           0.010942          -0.139400
# 5          -0.128678          -0.065718           0.026651          -0.171178
# 1          -0.132311          -0.079916           0.023946          -0.187638
# 7          -0.167087          -0.117079           0.048692          -0.133290
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.042188        0.087935                1
# 4        -0.050224        0.072057                2
# 5        -0.056959        0.086715                3
# 1        -0.060841        0.096238                4
# 7        -0.063957        0.093498                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.093
# R2: 0.334
# MSE: 0.076
# MAE: 0.053

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#           Date   Close  Target 7D  Pred Target 7D
# 964 2024-01-24  637.70     540.75          597.06
# 965 2024-01-25  637.40     537.95          591.80
# 966 2024-01-29  628.10     535.10          582.95
# 967 2024-01-30  615.90     524.35          574.94
# 968 2024-01-31  618.15     515.30          578.36
# 969 2024-02-01  579.75     500.05          541.08
# 970 2024-02-02  574.05     495.05          537.85
# 971 2024-02-05  540.75     490.80          513.29
# 972 2024-02-06  537.95     507.90          518.61
# 973 2024-02-07  535.10     494.50          519.40

# %% [markdown]
# ### `Target 15D`

# %%
target_col = target_cols[2]
X, y = get_training_data(target_col)
# Out:
# Target: Target 15D
# X.shape: (966, 41)
# y.shape: (966,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 100,
#  'max_samples': 1.0,
#  'max_features': 'log2',
#  'max_depth': 5}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.440998      0.103281         0.050910        0.007206
# 3        0.285633      0.008198         0.039690        0.007246
# 1        0.289370      0.027741         0.039578        0.005385
# 10       0.481232      0.065076         0.054673        0.003814
# 11       0.385115      0.019376         0.049487        0.005158
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 0                 100               1.0               log2               5
# 3                  75               1.0               0.25               4
# 1                  75               1.0               sqrt               5
# 10                125               1.0               log2               6
# 11                100              0.75               0.25               4
#
#                                                params  split0_test_score  \
# 0   {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.124055
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.110848
# 1   {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.163302
# 10  {'n_estimators': 125, 'max_samples': 1.0, 'max...           0.149121
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.129907
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.291138          -0.189313           0.021752
# 3           -0.399205          -0.179637           0.093160
# 1           -0.349136          -0.191741           0.066355
# 10          -0.386828          -0.179652           0.053117
# 11          -0.355900          -0.169621           0.066975
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.281088        -0.123147        0.167122                1
# 3           -0.265684        -0.128104        0.200567                2
# 1           -0.340820        -0.130408        0.210170                3
# 10          -0.292644        -0.131377        0.203130                4
# 11          -0.328757        -0.131479        0.199221                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.139
# R2: 0.463
# MSE: 0.102
# MAE: 0.075

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#           Date   Close  Target 15D  Pred Target 15D
# 956 2024-01-12  655.70      540.75           601.19
# 957 2024-01-15  647.65      537.95           587.61
# 958 2024-01-16  662.25      535.10           603.22
# 959 2024-01-17  653.60      524.35           594.02
# 960 2024-01-18  647.80      515.30           580.19
# 961 2024-01-19  644.75      500.05           575.19
# 962 2024-01-20  648.40      495.05           581.84
# 963 2024-01-23  628.90      490.80           585.58
# 964 2024-01-24  637.70      507.90           591.18
# 965 2024-01-25  637.40      494.50           593.02

# %% [markdown]
# ### `Target 30D`

# %%
target_col = target_cols[3]
X, y = get_training_data(target_col)
# Out:
# Target: Target 30D
# X.shape: (951, 41)
# y.shape: (951,)

# %%
model = get_model()
model.fit(X, y)
model.best_params_
# Out:
# {'n_estimators': 75, 'max_samples': 0.75, 'max_features': 0.25, 'max_depth': 5}

# %%
pd.DataFrame(model.cv_results_).sort_values('rank_test_score').iloc[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        0.296585      0.019688         0.037870        0.005568
# 8        0.390911      0.027473         0.051200        0.006485
# 11       0.377794      0.034224         0.048338        0.007109
# 3        0.307537      0.013938         0.044475        0.003186
# 6        0.542667      0.024674         0.060047        0.002889
#
#    param_n_estimators param_max_samples param_max_features param_max_depth  \
# 7                  75              0.75               0.25               5
# 8                 100               1.0               sqrt               4
# 11                100              0.75               0.25               4
# 3                  75               1.0               0.25               4
# 6                 125              0.75               0.25               5
#
#                                                params  split0_test_score  \
# 7   {'n_estimators': 75, 'max_samples': 0.75, 'max...           0.199526
# 8   {'n_estimators': 100, 'max_samples': 1.0, 'max...           0.200220
# 11  {'n_estimators': 100, 'max_samples': 0.75, 'ma...           0.164665
# 3   {'n_estimators': 75, 'max_samples': 1.0, 'max_...           0.230860
# 6   {'n_estimators': 125, 'max_samples': 0.75, 'ma...           0.180352
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 7           -0.500946          -0.625296          -0.090729
# 8           -0.430967          -0.461109          -0.106980
# 11          -0.544652          -0.603095          -0.066233
# 3           -0.613394          -0.555866          -0.044438
# 6           -0.533238          -0.680316          -0.139725
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 7           -0.159285        -0.235346        0.296114                1
# 8           -0.380586        -0.235884        0.251605                2
# 11          -0.215996        -0.253062        0.289248                3
# 3           -0.344336        -0.265435        0.318371                4
# 6           -0.183258        -0.271237        0.304946                5

# %%
feature_importances = feature_importances.join(
    pd.DataFrame(
        model.best_estimator_.feature_importances_,
        index = model.best_estimator_.feature_names_in_,
        columns = [target_col]
    )
)

preds = model.predict(X)
print_results(y, preds)
# Out:
# Target std: 0.202
# R2: 0.762
# MSE: 0.098
# MAE: 0.073

# %%
pred_col_name = f'Pred {target_col}'
expected_errors[pred_col_name] = expected_error(y, preds)

stock_df[pred_col_name] = (
    model.predict(standardized_df.drop(columns = target_cols)) * stock_df['Close']
).round(2)
stock_df[['Date', 'Close', target_col, pred_col_name]].dropna().iloc[-10:, :]
# Out:
#           Date   Close  Target 30D  Pred Target 30D
# 941 2023-12-21  663.85      540.75           607.24
# 942 2023-12-22  676.75      537.95           604.15
# 943 2023-12-26  673.95      535.10           597.89
# 944 2023-12-27  677.75      524.35           592.20
# 945 2023-12-28  675.80      515.30           596.41
# 946 2023-12-29  679.40      500.05           599.29
# 947 2024-01-01  687.80      495.05           614.82
# 948 2024-01-02  692.25      490.80           609.79
# 949 2024-01-03  686.80      507.90           613.89
# 950 2024-01-04  695.80      494.50           622.63

# %% [markdown]
# ## Feature importances

# %%
feature_importances['Mean'] = feature_importances.mean(axis = 1)
(feature_importances.sort_values('Mean', ascending = False) * 100).round(1)
# Out:
#                              Target 3D  Target 7D  Target 15D  Target 30D  \
# DayOfYear                          4.2        9.6         9.6        13.3
# 52W L                              3.3        5.6         8.1        12.2
# 52W H                              3.9        6.7         7.0        11.0
# Range 60MA                         3.4        6.5         8.3         6.2
# Month                              1.3        3.9         7.0        11.3
# Year                               1.5        5.4         6.1         9.3
# Range 30MA                         4.8        6.0         6.6         3.7
# Range 15MA                         3.4        4.3         5.8         3.2
# VWAP 60MA                          3.5        3.5         3.0         5.5
# Close 60MA                         3.0        3.5         3.7         4.3
# Range 7MA                          2.4        2.7         5.8         3.7
# VWAP 30MA                          4.2        2.9         2.3         3.0
# Close 30MA                         3.3        3.1         1.9         1.7
# Close 15MA                         3.5        2.0         1.9         1.0
# VWAP 15MA                          3.1        2.5         2.0         0.8
# Quarter                            0.5        1.7         3.1         2.1
# Day                                2.6        2.7         1.5         0.3
# VWAP 7MA                           3.3        1.3         1.3         0.3
# VWAP                               2.8        1.5         1.1         0.6
# Volume 60MA                        1.8        1.7         0.8         1.4
# #Trades 60MA                       2.7        1.3         0.9         0.4
# LTP                                2.5        1.6         0.9         0.2
# High                               3.1        1.4         0.5         0.3
# Value 7MA                          2.7        1.4         0.7         0.4
# #Trades 30MA                       3.0        1.5         0.4         0.3
# Value 60MA                         1.9        1.3         1.3         0.6
# #Trades 15MA                       2.4        1.6         0.6         0.4
# Close 7MA                          2.5        1.4         0.8         0.3
# Volume 7MA                         2.4        0.9         0.5         0.6
# Open                               2.4        1.5         0.3         0.2
# Volume 15MA                        1.9        1.8         0.6         0.1
# Low                                2.3        1.3         0.5         0.3
# #Trades 7MA                        2.3        1.2         0.6         0.1
# Value 15MA                         2.2        1.1         0.6         0.3
# DaysSinceLastTradingSession        0.2        1.2         2.4         0.1
# Value 30MA                         2.0        1.2         0.4         0.4
# Volume 30MA                        1.6        0.9         0.9         0.2
# Is52WHigh                          0.8        0.1         0.0         0.0
# Weekday                            0.6        0.1         0.1         0.0
# Is52WLow                           0.2        0.2         0.0         0.0
# IsGreen                            0.3        0.0         0.0         0.0
#
#                              Mean
# DayOfYear                     9.2
# 52W L                         7.3
# 52W H                         7.2
# Range 60MA                    6.1
# Month                         5.9
# Year                          5.6
# Range 30MA                    5.3
# Range 15MA                    4.2
# VWAP 60MA                     3.9
# Close 60MA                    3.6
# Range 7MA                     3.6
# VWAP 30MA                     3.1
# Close 30MA                    2.5
# Close 15MA                    2.1
# VWAP 15MA                     2.1
# Quarter                       1.8
# Day                           1.8
# VWAP 7MA                      1.5
# VWAP                          1.5
# Volume 60MA                   1.5
# #Trades 60MA                  1.3
# LTP                           1.3
# High                          1.3
# Value 7MA                     1.3
# #Trades 30MA                  1.3
# Value 60MA                    1.3
# #Trades 15MA                  1.3
# Close 7MA                     1.2
# Volume 7MA                    1.1
# Open                          1.1
# Volume 15MA                   1.1
# Low                           1.1
# #Trades 7MA                   1.1
# Value 15MA                    1.0
# DaysSinceLastTradingSession   1.0
# Value 30MA                    1.0
# Volume 30MA                   0.9
# Is52WHigh                     0.2
# Weekday                       0.2
# Is52WLow                      0.1
# IsGreen                       0.1

# %% [markdown]
# ## Forecasts

# %%
stock_df.filter(regex = "(Date)|(Close$)|(Pred.*)").iloc[-10:, :]
# Out:
#           Date   Close  Pred Target 3D  Pred Target 7D  Pred Target 15D  \
# 971 2024-02-05  540.75          531.78          513.29           549.37
# 972 2024-02-06  537.95          533.50          518.61           543.12
# 973 2024-02-07  535.10          527.78          519.40           537.19
# 974 2024-02-08  524.35          518.40          513.76           527.45
# 975 2024-02-09  515.30          508.18          501.94           518.31
# 976 2024-02-12  500.05          499.43          493.26           502.49
# 977 2024-02-13  495.05          494.25          484.23           497.11
# 978 2024-02-14  490.80          487.60          481.93           492.04
# 979 2024-02-15  507.90          503.15          491.31           500.06
# 980 2024-02-16  494.50          492.36          482.56           489.81
#
#      Pred Target 30D
# 971           544.21
# 972           542.17
# 973           543.65
# 974           535.83
# 975           521.33
# 976           503.84
# 977           494.44
# 978           491.21
# 979           499.20
# 980           494.52

# %%
latest_preds = stock_df.iloc[-1]
print(f"Date: {latest_preds['Date'].date()}")
print(f"Close: {latest_preds['Close']}")

for pred in expected_errors.keys():
    print(f"{pred}: {latest_preds[pred]} ± {expected_errors[pred] * latest_preds['Close']:.2f}")
# Out:
# Date: 2024-02-16
# Close: 494.5
# Pred Target 3D: 492.36 ± 23.68
# Pred Target 7D: 482.56 ± 37.41
# Pred Target 15D: 489.81 ± 50.25
# Pred Target 30D: 494.52 ± 48.69
